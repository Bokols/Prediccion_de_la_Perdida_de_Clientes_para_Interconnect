# %% [markdown]
#  # Hola &#x1F600;,
#
# Soy **Hesus Garcia** – **"Soy el único Hesus que conoces (y probablemente conocerás) 🌟"** – Sí, como "Jesús", pero con una H que me hace único. Puede sonar raro, pero créeme, ¡no lo olvidarás! Como tu revisor en Triple-Ten, estoy aquí para guiarte y ayudarte a mejorar tu código. Si algo necesita un ajuste, no hay de qué preocuparse; ¡aquí estoy para hacer que tu trabajo brille con todo su potencial! ✨
#
# Cada vez que encuentre un detalle importante en tu código, te lo señalaré para que puedas corregirlo y así te prepares para un ambiente de trabajo real, donde el líder de tu equipo actuaría de manera similar. Si en algún momento no logras solucionar el problema, te daré más detalles para ayudarte en nuestra próxima oportunidad de revisión.
#
# Es importante que cuando encuentres un comentario, **no los muevas, no los modifiques, ni los borres**.
#
# ---
#
# ### Formato de Comentarios
#
# Revisaré cuidadosamente cada implementación en tu notebook para asegurar que cumpla con los requisitos y te daré comentarios de acuerdo al siguiente formato:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - ¡Excelente trabajo! Esta parte está bien implementada y contribuye significativamente al análisis de datos o al proyecto. Continúa aplicando estas buenas prácticas en futuras secciones.
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Este código está correcto, pero se puede optimizar. Considera implementar mejoras para que sea más eficiente y fácil de leer. Esto fortalecerá la calidad de tu proyecto.
#
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>A resolver</b> ❗ - Aquí hay un problema o error en el código que es necesario corregir para aprobar esta sección. Por favor, revisa y corrige este punto, ya que es fundamental para la validez del análisis y la precisión de los resultados.
#
# </div>
#
# habilidades.
#
# Estos temas adicionales no son obligatorios en esta etapa, pero pueden serte útiles para profundizar en el futuro.
#
# ---
#
#
# Esta estructura en viñetas facilita la lectura y comprensión de cada parte del comentario final.
#
# También puedes responderme de la siguiente manera si tienes alguna duda o quieres aclarar algo específico:
#
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Aquí puedes escribir tu respuesta o pregunta sobre el comentario.
#
# </div>
#
#
# **¡Empecemos!** &#x1F680;

# %% [markdown]
# # Contenido <a id='back'></a>
#
# 1. [Introducción](#intro)
#     * [1.1 Servicios de Interconnect](#Servicios)
#     * [1.2 Objetivos](#objetivos)
#     * [1.3 Descripción de datos](#descripcion)
#     * [1.4 Plan de trabajo](#plan)
# 2. [Librerías y Datos](#librerias)
#     * [2.1 Librerías](#lib)
#     * [2.2 Cargar datos](#cargar)
# 3. [Exploración y preprocesamiento de DataFrames](#exploracion)
#     * [3.1 Preprocesamiento](#preprocesamiento)
#     * [3.2 Exploratory Data Analysis (EDA)](#exploratory)
# 4. [Preparación de datos](#prep)
#     * [4.1 Eliminación de datos irrelevantes](#elim)
#     * [4.2 Escalado de datos](#esca)
#     * [4.3 Codificación de variables](#codi)
#     * [4.4 División de datos](#divi)
#     * [4.5 Equilibrio de clases](#equi)
# 5. [Desarrollo de modelos](#mod0)
#     * [5.1 Modelo 1: Regresión logística](#mod1)
#     * [5.2 Modelo 2: Clasificador KNN](#mod2)
#     * [5.3 Modelo 3: Bosque aleatorio](#mod3)
#     * [5.4 Modelo 4: Búsqueda en cuadrícula + Bosque aleatorio](#mod4)
#     * [5.5 Modelo 5: Gradient Boosting Machine (GBM)](#mod5)
#     * [5.6 Modelo 6: Búsqueda en cuadrícula + Máquina de potenciación de gradiente (GBM)](#mod6)
#     * [5.7 Modelo 7: XGBoost (Extreme Gradient Boosting)](#mod7)
#     * [5.8 Modelo 8: Búsqueda en cuadrícula + XGBoost (Extreme Gradient Boosting)](#mod8)
#     * [5.9 Modelo 9: LightGBM](#mod9)
#     * [5.10 Modelo 10: Búsqueda en cuadrícula + LightGBM](#mod10)
# 6. [Evaluación del modelo](#eva0)
#     * [6.1 Análisis de resultados](#eva1)
#     * [6.2 Selección del modelo con el mejor rendimiento](#eva2)
#     * [6.3 Análisis del modelo con mejor desempeño](#eva2)
# 7. [Conclusiones del proyecto](#con0)
#     * [7.1 Resumen del proyecto](#con1)
#     * [7.2 Conclusión](#con2)
#     * [7.3 Posibilidades de mejora futuras](#con3)
# 8. [Informe de solución](#inf0)
#     * [8.1 ¿Qué pasos del plan se realizaron y qué pasos se omitieron?](#inf1)
#     * [8,2 ¿Qué dificultades encontraste y cómo lograste resolverlas?](#inf2)
#     * [8.3 ¿Cuáles fueron algunos de los pasos clave para resolver la tarea?](#inf3)
#     * [8.4 ¿Cuál es tu modelo final y qué nivel de calidad tiene?](#inf4)

# %% [markdown]
# # 1. Introducción <a id='intro'></a>

# %% [markdown]
# Al operador de telecomunicaciones Interconnect le gustaría poder pronosticar su tasa de cancelación de clientes. Si se descubre que un usuario o usuaria planea irse, se le ofrecerán códigos promocionales y opciones de planes especiales. El equipo de marketing de Interconnect ha recopilado algunos de los datos personales de sus clientes, incluyendo información sobre sus planes y contratos.

# %% [markdown]
# ## 1.1 Servicios de Interconnect <a id='servicios'></a>

# %% [markdown]
# Interconnect proporciona principalmente dos tipos de servicios:
#
# 1. Comunicación por teléfono fijo. El teléfono se puede conectar a varias líneas de manera simultánea.
# 2. Internet. La red se puede configurar a través de una línea telefónica (DSL, línea de abonado digital) o a través de un cable de fibra óptica.
#
# Algunos otros servicios que ofrece la empresa incluyen:
#
# - Seguridad en Internet: software antivirus (ProtecciónDeDispositivo) y un bloqueador de sitios web maliciosos (SeguridadEnLínea).
# - Una línea de soporte técnico (SoporteTécnico).
# - Almacenamiento de archivos en la nube y backup de datos (BackupOnline).
# - Streaming de TV (StreamingTV) y directorio de películas (StreamingPelículas).
#
# La clientela puede elegir entre un pago mensual o firmar un contrato de 1 o 2 años. Puede utilizar varios métodos de pago y recibir una factura electrónica después de una transacción.

# %% [markdown]
# ## 1.2 Objetivos <a id='objetivos'></a>

# %% [markdown]
# Los objetivos principales son:
#
# 1. Realizar una Exploración de Datos, analizando los diferentes Datasets.
# 2. Crear modelos de Machine Learning que permitirán predecir la probabilidad de cancelación de clientes.
# 3. Evaluar los modelos creados con la métrica principal AUC-ROC.
# 4. Preparar informe respectivo a los modelos y sus resultados.

# %% [markdown]
# ## 1.3 Descripción de datos <a id='descripcion'></a>

# %% [markdown]
# Los datos consisten en archivos obtenidos de diferentes fuentes:
#
# <code style="background:grey;color:black">contract.csv</code> - información del contracto;
# <br>
# <code style="background:grey;color:black">personal.csv</code> - datos personales del cliente;
# <br>
# <code style="background:grey;color:black">internet.csv</code> - información sobre los servicios de Internet;
# <br>
# <code style="background:grey;color:black">phone.csv</code> - información sobre los servicios telefónicos.
# <br>
#
# En cada archivo, la columna costumerID(ID de cliente) contiene un código único asignado a cada cliente.

# %% [markdown]
# ## 1.4 Plan de trabajo <a id='plan'></a>

# %% [markdown]
# Para poder cumplir con lo requerido para este proyecto, iniciaremos con las Librerías. Después con los Datos, los cuales abriremos y le echaremos un primer vistazo. Una vez visto y analizado si existen datos equivocados/faltantes, pasaremos a hacer la corrección respectiva. Analizaremos con gráficos algunas columnas que podrían tener algo en común por sobre la gente que ha cancelado sus planes con la compañía Interconnect. Una vez hechos los gráficos y analizados, hacemos una pequeña conclusión, respondiendo algunas preguntas. Además podríamos sacar una hipótesis.
#
# Posteriormente, avanzaremos con nuestros 6 modelos de Machine Learning. Los cuales serían:
#
# - Regresión Logística
# - DecisionTreeClassifier
# - RandomForestClassifier
# - CatBoost Classifier
# - LGBM Classifier
# - KNeighbors Classifier
#
# Y veremos cuál de estos modelos nos arroja el mejor resultado y a su vez, el "Most Important Feature", para poder indicar en dónde debe atacar la compañía Interconnect, para poder quizás retener a más clientes.

# %% [markdown]
# [Volver a Contenidos](#back)

# %% [markdown]
# # 2. Librerías y Datos <a id='librerias'></a>

# %% [markdown]
# ## 2.1 Librerías <a id='lib'></a>

# %%
import pandas as pd
import numpy as np
from functools import reduce

# Visualización de datos
import matplotlib.pyplot as plt

# Visualización de datos atractiva
import seaborn as sns

# Escalado de datos
from sklearn.preprocessing import MinMaxScaler

# División de datos
from sklearn.model_selection import train_test_split

# Shuffle data
from sklearn.utils import shuffle

# Modelos
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
import xgboost as xgb
import lightgbm as lgb

# Métricas
from sklearn.metrics import roc_curve, roc_auc_score, accuracy_score, f1_score, precision_score, recall_score, confusion_matrix, ConfusionMatrixDisplay

# Advertencias
import warnings

import time

# %% [markdown]
# ## 2.2 Cargar datos <a id='cargar'></a>

# %%
try:
    df_contract = pd.read_csv('contract.csv')
except:
    df_contract = pd.read_csv('C:/Users/bokol/OneDrive/Desktop/Tripleten/Sprints/Sprint 17/contract.csv')
try:
    df_personal = pd.read_csv('personal.csv')
except:
    df_personal = pd.read_csv('C:/Users/bokol/OneDrive/Desktop/Tripleten/Sprints/Sprint 17/personal.csv')
try:
    df_internet = pd.read_csv('internet.csv')
except:
    df_internet = pd.read_csv('C:/Users/bokol/OneDrive/Desktop/Tripleten/Sprints/Sprint 17/internet.csv')
try:
    df_phone = pd.read_csv('phone.csv')
except:
    df_phone = pd.read_csv('C:/Users/bokol/OneDrive/Desktop/Tripleten/Sprints/Sprint 17/phone.csv')

# %% [markdown]
# [Volver a Contenidos](#back)

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br> <b>Éxito</b> - ¡Bien hecho! La carga de datos está bien estructurada y manejas excepciones para diferentes rutas de archivo. Esto garantiza que el código sea más flexible y adaptable. 🔥👏</div>

# %% [markdown]
# ***
# ## 3. Exploración y preprocesamiento de DataFrames <a id='exploracion'></a>

# %% [markdown]
# ### 3.1 Preprocesamiento <a id='preprocesamiento'></a>

# %% [markdown]
# ### 3.1.1 df contrato

# %%
df_contract.head()
# Out:
#    customerID   BeginDate              EndDate            Type  \
# 0  7590-VHVEG  2020-01-01                   No  Month-to-month
# 1  5575-GNVDE  2017-04-01                   No        One year
# 2  3668-QPYBK  2019-10-01  2019-12-01 00:00:00  Month-to-month
# 3  7795-CFOCW  2016-05-01                   No        One year
# 4  9237-HQITU  2019-09-01  2019-11-01 00:00:00  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges
# 0              Yes           Electronic check           29.85        29.85
# 1               No               Mailed check           56.95       1889.5
# 2              Yes               Mailed check           53.85       108.15
# 3               No  Bank transfer (automatic)           42.30      1840.75
# 4              Yes           Electronic check           70.70       151.65

# %%
df_contract.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   object
#  2   EndDate           7043 non-null   object
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7043 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 440.3+ KB

# %%
print(f"La cantidad de filas duplicadas es: {df_contract.duplicated().sum()}.")
print(f"El porcentaje de filas duplicadas es: {df_contract.duplicated().sum()/len(df_contract):.2%}.")
df_contract.isna().sum()
# Out:
# La cantidad de filas duplicadas es: 0.
# El porcentaje de filas duplicadas es: 0.00%.
# customerID          0
# BeginDate           0
# EndDate             0
# Type                0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# dtype: int64

# %%
df_contract.describe()
# Out:
#        MonthlyCharges
# count     7043.000000
# mean        64.761692
# std         30.090047
# min         18.250000
# 25%         35.500000
# 50%         70.350000
# 75%         89.850000
# max        118.750000

# %%
# Comprobación de posibles problemas en las columnas

# Cantidad de valores
nunique_type = df_contract['Type'].nunique()
nunique_billing = df_contract['PaperlessBilling'].nunique()
nunique_payment = df_contract['PaymentMethod'].nunique()

# Valores únicos
values_type = df_contract['Type'].unique()
values_billing = df_contract['PaperlessBilling'].unique()
values_payment = df_contract['PaymentMethod'].unique()

#------------------------------------------------------------------------------#

# Imprimir "Type" cantidad y valores
print(f"Número de valores únicos en la columna 'Type': {nunique_type}")
for value in values_type:
    print(value)

print()

# Imprimir "PaperlessBilling" cantidad y valores

print(f"Número de valores únicos en la columna 'Paperlessbilling': {
      nunique_billing}")
for value in values_billing:
    print(value)

print()

# Imprimir "PaymentMethod" cantidad y valores
print(f"Número de valores únicos en la columna 'Paymentmethod' {
      nunique_payment}")
for value in values_payment:
    print(value)
# Out:
# Número de valores únicos en la columna 'Type': 3
# Month-to-month
# One year
# Two year
#
# Número de valores únicos en la columna 'Paperlessbilling': 2
# Yes
# No
#
# Número de valores únicos en la columna 'Paymentmethod' 4
# Electronic check
# Mailed check
# Bank transfer (automatic)
# Credit card (automatic)

# %% [markdown]
# #### Observaciones df_contract
# - No se observan valores faltantes en el DataFrame
# - La columna <code style="background:grey;color:black">ID de cliente</code> es importante porque es un identificador único para cada cliente. Se utilizará para fusionar los DataFrames más adelante.
# - Las columnas <code style="background:grey;color:black">BeginDate</code> y <code style="background:grey;color:black">EndDate</code> indican las fechas de inicio y finalización de los contratos (si es "No", significa que el contrato aún está activo; además, <code style="background:grey;color:black">EndDate</code> es la característica de destino)
# - La columna <code style="background:grey;color:black">PaymentMethod</code> contiene 3 valores categóricos únicos: "mes a mes", "un año" y "dos años".
# - La columna <code style="background:grey;color:black">PaperlessBilling</code> contiene 2 valores categóricos únicos: "Sí" y "No"
# - La columna <code style="background:grey;color:black">PaymentMethod</code> contiene 4 valores categóricos únicos: "Cheque electrónico", "Cheque enviado por correo", "Transferencia bancaria (automática)" y "Tarjeta de crédito (automática)".
# - La columna <code style="background:grey;color:black">MonthlyCharges</code> indica el cargo mensual por el servicio.
# - La columna <code style="background:grey;color:black">TotalCharges</code> indica los cargos totales acumulados.
#
# ##### Correcciones
# -  Los nombres de las columnas no siguen las mejores prácticas y se cambiarán.
# -  La columna <code style="background:grey;color:black">BeginDate</code> debe cambiarse del formato de objeto al formato DataTime.
# -  Para comprender mejor qué contratos están activos, crearé una nueva columna <code style="background:grey;color:black">service_status</code> que se basará en la columna <code style="background:grey;color:black">EndDate</code>.
# - La columna <code style="background:grey;color:black">TotalCharges</code> debe cambiar del tipo de objeto a Float64
#
# * NP. Más adelante manejaré todos los valores categóricos y los cambiaré a valores numéricos.

# %%
# Cambiar los nombres de las columnas para adaptarse a las mejores prácticas
df_contract.rename({"customerID":"customer_id", 
                    "BeginDate":"begin_date", 
                    "EndDate":"end_date", 
                    "Type":"type",
                    "PaperlessBilling":"paperless_billing",
                    "PaymentMethod":"payment_method",
                    "MonthlyCharges":"monthly_charges",
                    "TotalCharges":"total_charges",
                    }, axis = "columns",inplace = True)

# %%
# Agregar la columna service_status a DataFrame
active_contract = []
for value in df_contract['end_date']:
    if value != "No":
        active_contract.append("inactive")
    else:
        active_contract.append("active")
    
df_contract['service_status'] = active_contract

# %%
df_contract.head()
# Out:
#   customer_id  begin_date             end_date            type  \
# 0  7590-VHVEG  2020-01-01                   No  Month-to-month
# 1  5575-GNVDE  2017-04-01                   No        One year
# 2  3668-QPYBK  2019-10-01  2019-12-01 00:00:00  Month-to-month
# 3  7795-CFOCW  2016-05-01                   No        One year
# 4  9237-HQITU  2019-09-01  2019-11-01 00:00:00  Month-to-month
#
#   paperless_billing             payment_method  monthly_charges total_charges  \
# 0               Yes           Electronic check            29.85         29.85
# 1                No               Mailed check            56.95        1889.5
# 2               Yes               Mailed check            53.85        108.15
# 3                No  Bank transfer (automatic)            42.30       1840.75
# 4               Yes           Electronic check            70.70        151.65
#
#   service_status
# 0         active
# 1         active
# 2       inactive
# 3         active
# 4       inactive

# %%
df_contract.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        7043 non-null   object
#  1   begin_date         7043 non-null   object
#  2   end_date           7043 non-null   object
#  3   type               7043 non-null   object
#  4   paperless_billing  7043 non-null   object
#  5   payment_method     7043 non-null   object
#  6   monthly_charges    7043 non-null   float64
#  7   total_charges      7043 non-null   object
#  8   service_status     7043 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 495.3+ KB

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br> <b>Éxito</b> - ¡Buen trabajo en la exploración y preprocesamiento de los datos! Detectaste y aplicaste correcciones clave, como la conversión de fechas y valores numéricos, además de mejorar la estructura del DataFrame con nombres de columnas más claros. Estas acciones facilitarán el análisis posterior. 🚀👏</div>

# %% [markdown]
# ### 3.1.2 df personal

# %%
df_personal.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents
# 0  7590-VHVEG  Female              0     Yes         No
# 1  5575-GNVDE    Male              0      No         No
# 2  3668-QPYBK    Male              0      No         No
# 3  7795-CFOCW    Male              0      No         No
# 4  9237-HQITU  Female              0      No         No

# %%
df_personal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
print(f"La cantidad de filas duplicadas es: {df_personal.duplicated().sum()}.")
print(f"El porcentaje de filas duplicadas es: {df_personal.duplicated().sum()/len(df_personal):.2%}.")
df_personal.isna().sum()
# Out:
# La cantidad de filas duplicadas es: 0.
# El porcentaje de filas duplicadas es: 0.00%.
# customerID       0
# gender           0
# SeniorCitizen    0
# Partner          0
# Dependents       0
# dtype: int64

# %%
df_personal.describe()
# Out:
#        SeniorCitizen
# count    7043.000000
# mean        0.162147
# std         0.368612
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %%
# Cantidad de valores
nunique_gender = df_personal['gender'].nunique()
nunique_citizen = df_personal['SeniorCitizen'].nunique()
nunique_partner = df_personal['Partner'].nunique()
nunique_dependents = df_personal['Dependents'].nunique()

# Valores únicos
values_gender = df_personal['gender'].unique()
values_citizen = df_personal['SeniorCitizen'].unique()
values_partner = df_personal['Partner'].unique()
values_dependents = df_personal['Dependents'].unique()

# ------------------------------------------------------------------------------#

# Imprimir "gender" cantidad y valores
print(f"Número de valores únicos en la columna 'género': {
      nunique_gender}")
for value in values_gender:
    print(value)

print()

# Imprimir "SeniorCitizen" cantidad y valores
print(f"Número de valores únicos en la columna 'SeniorCitizen':  {
      nunique_citizen}")
for value in values_citizen:
    print(value)

print()

# Imprimir "Partner" cantidad y Partner
print(f"Número de valores únicos en la columna 'Partner': {
      nunique_partner}")
for value in values_partner:
    print(value)

print()

# Imprimir "Dependents" cantidad y valores
print(f"Número de valores únicos en la columna 'Dependents':  {
      nunique_dependents}")
for value in values_dependents:
    print(value)

print()
# Out:
# Número de valores únicos en la columna 'género': 2
# Female
# Male
#
# Número de valores únicos en la columna 'SeniorCitizen':  2
# 0
# 1
#
# Número de valores únicos en la columna 'Partner': 2
# Yes
# No
#
# Número de valores únicos en la columna 'Dependents':  2
# No
# Yes

# %% [markdown]
# #### Observaciones df_personal
# - No se observan valores faltantes en el DataFrame
# - La columna <code style="background:grey;color:black">customerID</code> es importante ya que es un identificador único para cada cliente. Esto se utilizará para fusionar los DataFrames más adelante.
# - La columna <code style="background:grey;color:black">gender </code> contiene 2 valores categóricos únicos: la columna contiene 2 valores categóricos únicos: "Female" y "Male"
# - La columna <code style="background:grey;color:black">SeniorCitizen</code> contiene 3 valores únicos: "0" y "1"
# - La columna <code style="background:grey;color:black">Partner </code> contiene 2 valores categóricos únicos: "Yes" y "No"
# - La columna <code style="background:grey;color:black">Dependents </code> contiene 2 valores categóricos únicos: "Yes" y "No"
#
# ##### Correcciones
# - Los nombres de las columnas no siguen las mejores prácticas y se cambiarán.
#
# * NP. Más adelante manejaré todos los valores categóricos y los cambiaré a valores numéricos.

# %%
# Changing column names to fit best practices
df_personal.rename({"customerID":"customer_id", 
                    "SeniorCitizen":"senior_citizen", 
                    "Partner":"partner", 
                    "Dependents":"dependents",
                    }, axis = "columns",inplace = True)

# %%
df_personal.head()
# Out:
#   customer_id  gender  senior_citizen partner dependents
# 0  7590-VHVEG  Female               0     Yes         No
# 1  5575-GNVDE    Male               0      No         No
# 2  3668-QPYBK    Male               0      No         No
# 3  7795-CFOCW    Male               0      No         No
# 4  9237-HQITU  Female               0      No         No

# %%
df_personal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     7043 non-null   object
#  1   gender          7043 non-null   object
#  2   senior_citizen  7043 non-null   int64
#  3   partner         7043 non-null   object
#  4   dependents      7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br> <b>Éxito</b> - ¡Gran trabajo en la exploración y preprocesamiento del DataFrame `df_personal`! Identificaste correctamente las características clave, aseguraste la limpieza de los datos y aplicaste buenas prácticas al renombrar las columnas. Además, tu plan para transformar los valores categóricos en numéricos más adelante demuestra una visión estructurada del análisis. 🚀👏</div>

# %% [markdown]
# ### 3.1.3 df internet

# %%
df_internet.head()
# Out:
#    customerID InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0  7590-VHVEG             DSL             No          Yes               No
# 1  5575-GNVDE             DSL            Yes           No              Yes
# 2  3668-QPYBK             DSL            Yes          Yes               No
# 3  7795-CFOCW             DSL            Yes           No              Yes
# 4  9237-HQITU     Fiber optic             No           No               No
#
#   TechSupport StreamingTV StreamingMovies
# 0          No          No              No
# 1          No          No              No
# 2          No          No              No
# 3         Yes          No              No
# 4          No          No              No

# %%
df_internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5517 entries, 0 to 5516
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        5517 non-null   object
#  1   InternetService   5517 non-null   object
#  2   OnlineSecurity    5517 non-null   object
#  3   OnlineBackup      5517 non-null   object
#  4   DeviceProtection  5517 non-null   object
#  5   TechSupport       5517 non-null   object
#  6   StreamingTV       5517 non-null   object
#  7   StreamingMovies   5517 non-null   object
# dtypes: object(8)
# memory usage: 344.9+ KB

# %%
print(f"La cantidad de filas duplicadas es: {df_internet.duplicated().sum()}.")
print(f"El porcentaje de filas duplicadas es: {df_internet.duplicated().sum()/len(df_internet):.2%}.")
df_internet.isna().sum()
# Out:
# La cantidad de filas duplicadas es: 0.
# El porcentaje de filas duplicadas es: 0.00%.
# customerID          0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# dtype: int64

# %%
df_internet.describe()
# Out:
#         customerID InternetService OnlineSecurity OnlineBackup  \
# count         5517            5517           5517         5517
# unique        5517               2              2            2
# top     7590-VHVEG     Fiber optic             No           No
# freq             1            3096           3498         3088
#
#        DeviceProtection TechSupport StreamingTV StreamingMovies
# count              5517        5517        5517            5517
# unique                2           2           2               2
# top                  No          No          No              No
# freq               3095        3473        2810            2785

# %%
# Cantidad de valores
nunique_internet = df_internet['InternetService'].nunique()
nunique_security = df_internet['OnlineSecurity'].nunique()
nunique_backup = df_internet['OnlineBackup'].nunique()
nunique_protection = df_internet['DeviceProtection'].nunique()
nunique_tech = df_internet['TechSupport'].nunique()
nunique_tv = df_internet['StreamingTV'].nunique()
nunique_movies = df_internet['StreamingMovies'].nunique()

# Valores únicos
values_internet = df_internet['InternetService'].unique()
values_security = df_internet['OnlineSecurity'].unique()
values_backup = df_internet['OnlineBackup'].unique()
values_protection = df_internet['DeviceProtection'].unique()
values_tech = df_internet['TechSupport'].unique()
values_tv = df_internet['StreamingTV'].unique()
values_movies = df_internet['StreamingMovies'].unique()

# ------------------------------------------------------------------------------#

# Imprimir "InternetService" cantidad y valores
print(f"Número de valores únicos en la columna 'InternetService':  {
      nunique_internet}")
for value in values_internet:
    print(value)

print()

# Imprimir "OnlineSecurity" cantidad y valores
print(f"Número de valores únicos en la columna 'OnlineSecurity': {nunique_security}")
for value in values_security:
    print(value)

print()

# Imprimir "OnlineBackup" cantidad y valores
print(f"Número de valores únicos en la columna 'OnlineBackup':{nunique_backup}")
for value in values_backup:
    print(value)

print()

# Imprimir "DeviceProtection" cantidad y valores
print(f"Número de valores únicos en la columna 'DeviceProtection':  {nunique_protection}")
for value in values_protection:
    print(value)

print()

# Imprimir "TechSupport" cantidad y valores
print(f"Número de valores únicos en la columna 'TechSupport': {nunique_tech}")
for value in values_tech:
    print(value)

print()

# Imprimir "StreamingTV" cantidad y valores
print(f"Número de valores únicos en la columna 'StreamingTV': {nunique_tv}")
for value in values_tv:
    print(value)

print()

# Imprimir "StreamingMovies" cantidad y valores
print(f"Número de valores únicos en la columna 'StreamingMovies': {nunique_movies}")
for value in values_movies:
    print(value)

print()
# Out:
# Número de valores únicos en la columna 'InternetService':  2
# DSL
# Fiber optic
#
# Número de valores únicos en la columna 'OnlineSecurity': 2
# No
# Yes
#
# Número de valores únicos en la columna 'OnlineBackup':2
# Yes
# No
#
# Número de valores únicos en la columna 'DeviceProtection':  2
# No
# Yes
#
# Número de valores únicos en la columna 'TechSupport': 2
# No
# Yes
#
# Número de valores únicos en la columna 'StreamingTV': 2
# No
# Yes
#
# Número de valores únicos en la columna 'StreamingMovies': 2
# No
# Yes

# %% [markdown]
# #### Observaciones df_internet
# - No se observaron valores faltantes en DataFrame
# - La columna <code style="background:grey;color:black">customerID</code> es importante ya que es un identificador único para cada cliente. Esto se utilizará para fusionar los DataFrames más adelante. - La columna <code style="background:grey;color:black">InternetService</code> contiene 2 valores categóricos únicos: la columna contiene 2 valores categóricos únicos: "DSL" y "Fiber optic"
# - La columna <code style="background:grey;color:black">OnlineSecurity</code> contiene 3 valores categóricos únicos: "Yes" y "No"
# - La columna <code style="background:grey;color:black">OnlineBackup </code> contiene 2 valores categóricos únicos: "Yes" y "No"
# - La columna <code style="background:grey;color:black">DeviceProtection </code> contiene 2 valores categóricos únicos: "Yes" y "No"
# - La columna <code style="background:grey;color:black">TechSupport </code> contiene 2 valores categóricos únicos: "Yes" y "No"
# - La columna <code style="background:grey;color:black">StreamingTV </code> contiene 2 valores categóricos únicos: "Yes" y "No"
# - La columna <code style="background:grey;color:black">StreamingMovies</code> contiene 2 valores categóricos únicos: "Yes" y "No"
#
#
# ##### Correcciones
# - Los nombres de las columnas no siguen las mejores prácticas y se cambiarán.
#
# * NP. Más adelante, manejaré todos los valores categóricos y los cambiaré a valores numéricos.

# %%
# Cambiar los nombres de las columnas para adaptarse a las mejores prácticas
df_internet.rename({"customerID":"customer_id", 
                    "InternetService":"internet_service", 
                    "OnlineSecurity":"online_security", 
                    "OnlineBackup":"online_backup",
                    "DeviceProtection":"device_protection",
                    "TechSupport":"tech_support",
                    "StreamingTV":"streaming_tv",
                    "StreamingMovies":"streaming_movies",
                    }, axis = "columns",inplace = True)

# %%
df_internet.head()
# Out:
#   customer_id internet_service online_security online_backup  \
# 0  7590-VHVEG              DSL              No           Yes
# 1  5575-GNVDE              DSL             Yes            No
# 2  3668-QPYBK              DSL             Yes           Yes
# 3  7795-CFOCW              DSL             Yes            No
# 4  9237-HQITU      Fiber optic              No            No
#
#   device_protection tech_support streaming_tv streaming_movies
# 0                No           No           No               No
# 1               Yes           No           No               No
# 2                No           No           No               No
# 3               Yes          Yes           No               No
# 4                No           No           No               No

# %%
df_internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5517 entries, 0 to 5516
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        5517 non-null   object
#  1   internet_service   5517 non-null   object
#  2   online_security    5517 non-null   object
#  3   online_backup      5517 non-null   object
#  4   device_protection  5517 non-null   object
#  5   tech_support       5517 non-null   object
#  6   streaming_tv       5517 non-null   object
#  7   streaming_movies   5517 non-null   object
# dtypes: object(8)
# memory usage: 344.9+ KB

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br> <b>Éxito</b> - ¡Muy bien hecho en el análisis y preprocesamiento del DataFrame `df_internet`! Identificaste correctamente las características clave, aseguraste que los datos estén limpios y aplicaste buenas prácticas en la renombración de columnas. También es excelente que ya tengas en cuenta la transformación de valores categóricos en numéricos para futuros análisis. ¡Sigue así! 🚀👏</div>

# %% [markdown]
# ### 3.1.4 df phone

# %%
df_phone.head()
# Out:
#    customerID MultipleLines
# 0  5575-GNVDE            No
# 1  3668-QPYBK            No
# 2  9237-HQITU            No
# 3  9305-CDSKC           Yes
# 4  1452-KIOVK           Yes

# %%
df_phone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6361 entries, 0 to 6360
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     6361 non-null   object
#  1   MultipleLines  6361 non-null   object
# dtypes: object(2)
# memory usage: 99.5+ KB

# %%
print(f"La cantidad de filas duplicadas es: {df_phone.duplicated().sum()}.")
print(f"El porcentaje de filas duplicadas es: {df_phone.duplicated().sum()/len(df_phone):.2%}.")
df_phone.isna().sum()
# Out:
# La cantidad de filas duplicadas es: 0.
# El porcentaje de filas duplicadas es: 0.00%.
# customerID       0
# MultipleLines    0
# dtype: int64

# %%
df_phone.describe()
# Out:
#         customerID MultipleLines
# count         6361          6361
# unique        6361             2
# top     5575-GNVDE            No
# freq             1          3390

# %%
# Cantidad de valores
nunique_lines = df_phone['MultipleLines'].nunique()

# Valores únicos
values_lines = df_phone['MultipleLines'].unique()

# ------------------------------------------------------------------------------#

# Imprimir "MultipleLines" cantidad y valores
print(f"Número de valores únicos en la columna 'MultipleLines':  {nunique_lines}")
for value in values_lines:
    print(value)

print()
# Out:
# Número de valores únicos en la columna 'MultipleLines':  2
# No
# Yes

# %% [markdown]
# #### Observaciones df_phone
# - No se observaron valores faltantes en DataFrame
# - La columna <code style="background:grey;color:black">customerID</code> es importante ya que es un identificador único para cada cliente. Esto se utilizará para fusionar los DataFrames más adelante.
# - La columna <code style="background:grey;color:black">MultipleLines</code> contiene 2 valores categóricos únicos: la columna contiene 2 valores categóricos únicos: "Yes" y "No"
#
# ##### Correcciones
# - Los nombres de las columnas no siguen las mejores prácticas y se cambiarán.
#
# * NP. Más adelante, manejaré todos los valores categóricos y los cambiaré a valores numéricos.

# %%
# Changing column names to fit best practices
df_phone.rename({"customerID":"customer_id", 
                    "MultipleLines":"multiple_lines", 
                    }, axis = "columns",inplace = True)

# %%
df_phone.head()
# Out:
#   customer_id multiple_lines
# 0  5575-GNVDE             No
# 1  3668-QPYBK             No
# 2  9237-HQITU             No
# 3  9305-CDSKC            Yes
# 4  1452-KIOVK            Yes

# %%
df_phone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6361 entries, 0 to 6360
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     6361 non-null   object
#  1   multiple_lines  6361 non-null   object
# dtypes: object(2)
# memory usage: 99.5+ KB

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br> <b>Éxito</b> - ¡Buen trabajo en la limpieza y estandarización del DataFrame `df_phone`! Has identificado correctamente la estructura de los datos, asegurado la ausencia de valores nulos y aplicado buenas prácticas en la renombración de columnas. Además, es excelente que ya estés considerando la transformación de valores categóricos en numéricos para futuras etapas del análisis. ¡Sigue así! 🚀👏</div>

# %% [markdown]
# [Volver a Contenidos](#back)

# %% [markdown]
# ### 3.2 Exploratory Data Analysis (EDA) <a id='exploratory'></a>

# %% [markdown]
# En el EDA me gustaría explorar los siguientes temas para entender mejor los datos.
#
# 1. ¿Cuál es la proporción de contratos activos e inactivos?
# 2. ¿Cómo es la evolución de los contratos a lo largo del tiempo?
# 3. ¿Cuál es la duración del contrato?
# 4. ¿Cuál es la distribución de la duración del contrato?
# 5. ¿Cómo se utilizan las características del servicio de Internet?
# 6. ¿Cuáles son las características del cliente?
# 7. ¿Qué tipos de contratos y cargos existen?
# 8. ¿Cuáles son los métodos de pago?

# %% [markdown]
# #### 3.2.1 Fusionar DataFrames
# - Antes de continuar con la EDA, fusionaré todos los DataFrames en uno solo.
# - Para fusionar los DataFrames, usaré el parámetro "outer" para asegurar que se conserven todas las filas de todas las tablas que se fusionarán.

# %%
# Fusión de DataFrame
dfs = [df_contract, df_personal, df_internet, df_phone]

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['customer_id'],how='outer'), dfs)

# %%
# La forma
print("Número de filas y columnas para un DataFrame combinado:")
print(df_merged.shape)

# Imprimir
df_merged.info()
display(df_merged.head())
# Out:
# Número de filas y columnas para un DataFrame combinado:
# (7043, 21)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        7043 non-null   object
#  1   begin_date         7043 non-null   object
#  2   end_date           7043 non-null   object
#  3   type               7043 non-null   object
#  4   paperless_billing  7043 non-null   object
#  5   payment_method     7043 non-null   object
#  6   monthly_charges    7043 non-null   float64
#  7   total_charges      7043 non-null   object
#  8   service_status     7043 non-null   object
#  9   gender             7043 non-null   object
#  10  senior_citizen     7043 non-null   int64
#  11  partner            7043 non-null   object
#  12  dependents         7043 non-null   object
#  13  internet_service   5517 non-null   object
# ...

# %% [markdown]
# #### 3.2.2 Tipos de datos

# %% [markdown]
# - Para facilitar el análisis de fechas en el conjunto de datos, se cambia el tipo de datos de dos columnas del DataFrame, <code style="background:grey;color:black">begindate</code>  y <code style="background:grey;color:black">enddate</code> (primero se reemplazan los valores "No" por valores nulos).
# - La columna <code style="background:grey;color:black">totalcharges</code> debe convertirse de tipo objeto a tipo numérico.

# %%
# Cambiar el tipo de datos al formato DateTime
df_merged['begin_date'] = pd.to_datetime(df_merged['begin_date'])

# %%
# Convertir 'No' en NaN
df_merged['end_date'] = df_merged['end_date'].replace('No', np.nan)

# Cambiar el tipo de datos
df_merged['end_date'] = pd.to_datetime(df_merged['end_date'])

# %%
# Convertir 'total_charges' a numérica
df_merged['total_charges'] = pd.to_numeric(df_merged['total_charges'], errors='coerce')

# %%
# Eliminar valores NaN para el marco de datos en 'total_charges'
df_merged = df_merged.dropna(subset=['total_charges'])

# DataFrame properties
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        7032 non-null   object
#  1   begin_date         7032 non-null   datetime64[ns]
#  2   end_date           1869 non-null   datetime64[ns]
#  3   type               7032 non-null   object
#  4   paperless_billing  7032 non-null   object
#  5   payment_method     7032 non-null   object
#  6   monthly_charges    7032 non-null   float64
#  7   total_charges      7032 non-null   float64
#  8   service_status     7032 non-null   object
#  9   gender             7032 non-null   object
#  10  senior_citizen     7032 non-null   int64
#  11  partner            7032 non-null   object
#  12  dependents         7032 non-null   object
#  13  internet_service   5512 non-null   object
#  14  online_security    5512 non-null   object
# ...

# %% [markdown]
# #### 3.2.3 Estadísticas descriptivas

# %% [markdown]
# - Las estadísticas descriptivas básicas proporcionan un resumen rápido y útil de los datos numéricos presentes en "df_merged", ayudando a comprender las características generales de los datos.
# - Se observa que las fechas de inicio de los contratos van desde 2013 hasta 2020, mientras que las fechas de finalización se concentran en 2019 y 2020.

# %%
# Estadísticas descriptivas
df_merged.describe()
# Out:
#                           begin_date                       end_date  \
# count                           7032                           1869
# mean   2017-04-28 23:14:44.641638400  2019-11-15 21:31:18.009630976
# min              2013-10-01 00:00:00            2019-10-01 00:00:00
# 25%              2015-06-01 00:00:00            2019-11-01 00:00:00
# 50%              2017-09-01 00:00:00            2019-11-01 00:00:00
# 75%              2019-04-01 00:00:00            2019-12-01 00:00:00
# max              2020-01-01 00:00:00            2020-01-01 00:00:00
# std                              NaN                            NaN
#
#        monthly_charges  total_charges  senior_citizen
# count      7032.000000    7032.000000     7032.000000
# mean         64.798208    2283.300441        0.162400
# min          18.250000      18.800000        0.000000
# 25%          35.587500     401.450000        0.000000
# 50%          70.350000    1397.475000        0.000000
# ...

# %% [markdown]
# #### 3.2.4 ¿Cuál es la proporción de contratos activos e inactivos?

# %% [markdown]
# - Para identificar y contabilizar los contratos que están activos en el conjunto de datos, se seleccionan todos los registros en "df_merged" donde la columna <code style="background:grey;color:black">enddate</code> contiene una fecha de finalización del contrato.
# - Esta separación en los datos será la base de una parte importante de las exploraciones y análisis iniciales de este proyecto.

# %%
# Contratos activos
active_contracts = df_merged[df_merged['end_date'].isnull()]
count_active_contracts = active_contracts.shape[0]

# Contratos inactivos
finished_contracts = df_merged[df_merged['end_date'].notna()]
count_finished_contracts = finished_contracts.shape[0]

# %%
# Tamaño del gráfico
fig, axs = plt.subplots(1, 2, figsize=(12, 4))

# Subplot 1: Contar contratos
sns.barplot(x=['Active Contracts', 'Inactive Contracts'], y=[
            count_active_contracts, count_finished_contracts], ax=axs[0])

# Título
axs[0].set_title('Número de contratos activos e inactivos')
axs[0].set_xlabel('Estado del contrato')
axs[0].set_ylabel('Número de contratos')


# Contar anotaciones 
for p in axs[0].patches:
    axs[0].annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center', xytext=(0, -20), textcoords='offset points', fontsize=10)

# Subplot 2: Porcentaje de contratos
labels = ['Active Contracts', 'Inactive Contracts']
sizes = [count_active_contracts, count_finished_contracts]
colors = ['green', 'red']
explode = (0.1, 0)  

# Gráfico circular
axs[1].pie(sizes, explode=explode, labels=labels, colors=['green', 'grey'],
           autopct='%1.1f%%', shadow=True, startangle=140)

# Título
axs[1].set_title('Proporción de contratos activos e inactivos')

# Imprimir
plt.tight_layout()
plt.show()

# %% [markdown]
# - Para comparar visualmente la proporción de contratos activos e inactivos, se muestra un gráfico de barras con la representación absoluta y un gráfico circular para su proporción relativa respecto del total de contratos.
# - Se observa que la mayoría de los contratos se encuentran activos, representando el **73.5% del total**. Entender esta distribución es importante para desarrollar estrategias de retención de clientes.

# %% [markdown]
# #### 3.2.5 ¿Cómo es la evolución de los contratos a lo largo del tiempo?

# %% [markdown]
# - Dividir los datos en contratos activos y contratos inactivos (o finalizados) y contar cada año nos permite entender cómo varía el número de contratos a lo largo del tiempo.

# %%
# Contratos activos
active_contracts = df_merged[df_merged['end_date'].isnull()]

# Contratos inactivos
finished_contracts = df_merged[df_merged['end_date'].notna()]

# Años ordenados
years = sorted(df_merged['begin_date'].dt.year.unique())

# Inicialización de contadores
active_counts = []
finished_counts = []

# Bucle
for year in years:
    # Nuevos contratos activos
    active_year = active_contracts[active_contracts['begin_date'].dt.year == year].shape[0]

    # Contratos finalizados
    finished_year = finished_contracts[finished_contracts['end_date'].dt.year == year].shape[0]

    # Añadir
    active_counts.append(active_year)
    finished_counts.append(finished_year)

# Imprimir
print(active_counts)
print(finished_counts)
# Out:
# [0, 1246, 729, 618, 646, 715, 976, 233]
# [0, 0, 0, 0, 0, 0, 1409, 460]

# %%
# Tamaño y configuración del gráfico
bar_width = 0.35
index = np.arange(len(years))
plt.figure(figsize=(10, 4))

# Barras de contratos activos y finalizados
bars1 = plt.bar(index - bar_width/2, active_counts, bar_width,
                label='Active contracts', color='green', alpha=0.7)
bars2 = plt.bar(index + bar_width/2, finished_counts, bar_width,
                label='Inactive contracts', color='red', alpha=0.7)

# Título
plt.title('Recuento de contratos activos e inactivos por año')
plt.xlabel('Año')
plt.ylabel('Número de contratos')
plt.xticks(index, years)  # Etiquetas del eje X
plt.legend()

# Contar
for bars in [bars1, bars2]:
    for bar in bars:
        height = bar.get_height()
        if height != 0: #Cuente solo si el valor es diferente de 0
            plt.gca().annotate(format(height, '.0f'),
                               (bar.get_x() + bar.get_width() / 2., height),
                               ha='center', va='center', xytext=(0, -20),
                               textcoords='offset points', fontsize=10)

# Imprimir
plt.tight_layout()
plt.show()

# %% [markdown]
# - Los Contratos Nuevos Activos comienzan en 0 en el primer año, aumentan significativamente en el segundo año (1246) y luego disminuyen gradualmente en los años siguientes. Hay un ligero aumento del quinto año (646) al séptimo año (976), pero cae drásticamente en el octavo y último año de los datos (233).
# - Por otro lado, los Contratos Inactivos/Cancelados no tienen registros durante los primeros seis años, lo que indica una retención completa durante ese período. Sin embargo, a partir del séptimo año, hay un aumento significativo en los contratos inactivos o cancelaciones, con 1409 registros en el séptimo año y 460 en el octavo año.
# - Comprender estas fluctuaciones ayuda a identificar posibles cambios en la adquisición de nuevos clientes o la retención de los existentes a lo largo de los años. El aumento repentino de las cancelaciones en el séptimo año puede deberse a varios factores como la insatisfacción del cliente, los cambios en el mercado o la competencia.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - ¡Buen trabajo! Has estructurado un análisis exploratorio detallado y bien fundamentado. La integración de gráficos y estadísticas descriptivas proporciona información valiosa sobre la evolución de los contratos y la retención de clientes. Sigue aplicando este enfoque analítico en las siguientes etapas del proyecto. ¡Sigue así! 🚀</div>

# %% [markdown]
# ### 3.2.6 Ingeniería de características

# %% [markdown]
# ##### Contratos activos
# - A continuación, utilizamos la presencia de valores NaN en la columna <code style="background:grey;color:black">enddate</code> para crear una columna adicional <code style="background:grey;color:black">active_contract</code> que representa si el contrato está activo o no, lo que facilita un mayor análisis y la creación de modelos.
# - Esta nueva serie puede servir como la nueva función de destino con dos valores únicos para contratos activos e inactivos ('True' y 'False'), lo que nos permite mantener la columna <code style="background:grey;color:black">enddate</code> como tipo fecha y conservar todos sus valores de fecha.

# %%
# New Series
df_merged['active_contract'] = df_merged['end_date'].isnull()

# Print
display(df_merged.head())
# Out:
#   customer_id begin_date   end_date            type paperless_billing  \
# 0  0002-ORFBO 2019-05-01        NaT        One year               Yes
# 1  0003-MKNFE 2019-05-01        NaT  Month-to-month                No
# 2  0004-TLHLJ 2019-09-01 2020-01-01  Month-to-month               Yes
# 3  0011-IGKFF 2018-12-01 2020-01-01  Month-to-month               Yes
# 4  0013-EXCHZ 2019-09-01 2019-12-01  Month-to-month               Yes
#
#      payment_method  monthly_charges  total_charges service_status  gender  \
# 0      Mailed check             65.6         593.30         active  Female
# 1      Mailed check             59.9         542.40         active    Male
# 2  Electronic check             73.9         280.85       inactive    Male
# 3  Electronic check             98.0        1237.85       inactive    Male
# 4      Mailed check             83.9         267.40       inactive  Female
#
#    ...  dependents internet_service online_security online_backup  \
# ...

# %% [markdown]
# ### 3.2.7 ¿Cuál es la duración del contrato?
# - A partir de los datos existentes se crea una nueva serie <code style="background:grey;color:black">duration_days</code> para facilitar el análisis de los contratos finalizados.
# - El cálculo y visualización de la duración en días de los contratos finalizados proporciona información útil para analizar la distribución y las características de estos contratos a lo largo del tiempo.

# %%
# Nuevo DataFrame
contracts_dates = df_merged[['begin_date', 'end_date']].copy()

# Nueva serie
df_merged['duration_days'] = (contracts_dates['end_date'] - contracts_dates['begin_date']).dt.days.astype('Int64')

# Imprimir
display(df_merged[['begin_date', 'end_date', 'duration_days']].head(5))
# Out:
#   begin_date   end_date  duration_days
# 0 2019-05-01        NaT           <NA>
# 1 2019-05-01        NaT           <NA>
# 2 2019-09-01 2020-01-01            122
# 3 2018-12-01 2020-01-01            396
# 4 2019-09-01 2019-12-01             91

# %% [markdown]
# ##### Distribución de la duración de los contratos
# - Las estadísticas descriptivas brindan información valiosa sobre la duración de los contratos.
# - El diagrama de caja ofrece una visualización gráfica de la distribución de los datos.

# %%
df_merged['duration_days'].describe()
# Out:
# count        1869.0
# mean      547.35206
# std      594.389607
# min            30.0
# 25%            61.0
# 50%           304.0
# 75%           883.0
# max          2191.0
# Name: duration_days, dtype: Float64

# %%
# Copia de contratos terminados
finished_contracts = df_merged[df_merged['end_date'].notna()].copy()

# Días de duración de los contratos finalizados
finished_contracts['duration_days'] = (
    finished_contracts['end_date'] - finished_contracts['begin_date']).dt.days

# Gráfico
plt.figure(figsize=(10, 4))

# Boxplot
sns.boxplot(x='duration_days', data=finished_contracts,
            color='skyblue')
plt.xlabel('Duración (días)')
plt.title('Distribución de la duración de los contratos completados')
plt.grid(True)

# Puntos de datos clave
desc_stats = finished_contracts['duration_days'].describe()
stats_str = f'Mediana: {desc_stats["50%"]}\nQ1: {desc_stats["25%"]}\nQ3: {
    desc_stats["75%"]}\nMin: {desc_stats["min"]}\nMax: {desc_stats["max"]}'

plt.annotate(stats_str,
             xy=(0.95, 0.5),
             xycoords='axes fraction',
             xytext=(-10, 0),
             textcoords='offset points',
             ha='right', va='center',
             fontsize=10,
             bbox=dict(boxstyle='round,pad=0.5', fc='lightyellow', alpha=0.7))

# Imprimir
plt.tight_layout()
plt.show()

# %% [markdown]
# - Se han ejecutado un total de 1.869 contratos.
# - La duración media de estos contratos es de aproximadamente 547 días.
# - La mayoría de los contratos tienen una duración concentrada entre aproximadamente 61 y 883 días, como lo indica el rango intercuartil (25%: 61 días | 50%: 304 días | 75%: 883 días).
# - La variabilidad en la duración de los contratos tiene una desviación típica de aproximadamente 594 días.
# - El contrato más corto tiene una duración de 30 días, mientras que el más largo tiene una duración de 2.191 días, lo que indica un amplio rango de valores atípicos hacia la duración máxima.

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br> <b>Éxito</b> - ¡Gran trabajo en la ingeniería de características! La creación de las columnas `active_contract` y `duration_days` facilita considerablemente el análisis y la futura modelización. Además, la exploración de la distribución de la duración de los contratos proporciona información valiosa para comprender el comportamiento de los clientes. Continúa aplicando estas técnicas en el resto del análisis. 🚀</div>

# %% [markdown]
# ### 3.2.8 ¿Cómo se utilizan las características del servicio de Internet?

# %% [markdown]
# - Para analizar los resultados de los servicios y entender los patrones de comportamiento entre los usuarios que cancelan sus contratos y los que mantienen contratos activos, examinaremos a continuación cada uno de ellos.

# %%
# Categorías
categories = ['online_security', 'online_backup', 'device_protection',
              'tech_support', 'streaming_tv', 'streaming_movies', 'paperless_billing', 'multiple_lines', 'internet_service']

# Paleta de colores
custom_palette = {'No': 'gray', 'Yes': 'lightgreen',
                  'Fiber optic': 'skyblue', 'DSL': 'skyblue'}

# Tamaño del gráfico
plt.figure(figsize=(14, 20))

# Bucle
for i, category in enumerate(categories, 1):
    # Subtrama de contratos activos
    plt.subplot(len(categories), 2, 2*i - 1)
    ax = sns.countplot(x=category, data=active_contracts,
                       hue=category, palette=custom_palette)
    
    # Título
    plt.title(f'Active Contracts - {category}')
    #plt.xlabel(category)
    plt.ylabel('Quantity')

    # Contar
    for p in ax.patches:
        ax.annotate(format(p.get_height(), '.0f'),
                    (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center', xytext=(0, -15),
                    textcoords='offset points', fontsize=12)

    # Subtrama de contratos inactivos
    plt.subplot(len(categories), 2, 2*i)
    ax = sns.countplot(x=category, data=finished_contracts,
                       hue=category, palette=custom_palette)
    
    # Título
    plt.title(f'Inactive Contracts - {category}')
    #plt.xlabel(category)
    plt.ylabel('Quantity')

    # Contar
    for p in ax.patches:
        ax.annotate(format(p.get_height(), '.0f'),
                    (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center', xytext=(0, -15),
                    textcoords='offset points', fontsize=12)

# Imprimir
plt.tight_layout()
plt.show()

# %% [markdown]
# - **online_security:** Tanto los contratos activos como los inactivos tienden a tener menos seguridad en línea, pero esto es mucho más pronunciado en los contratos inactivos. Por lo tanto, la falta de seguridad en línea puede ser un factor que influya en las cancelaciones de contratos.
# - **online Backup:** Los contratos activos tienen más copias de seguridad en línea que los contratos inactivos, por lo que este servicio podría ser otro factor de retención.
# - **device_protection:** Al igual que los dos servicios anteriores, los contratos activos tienen más protección del dispositivo en comparación con los contratos inactivos.
# - **tech_support:** Tanto los usuarios activos como los inactivos tienden a tener menos acceso al soporte técnico, pero la diferencia es mucho más pronunciada en los contratos inactivos. Esto sugiere que un buen soporte técnico puede ser crucial para la retención de clientes.
# - **streaming_tv y streaming_movies:** Ambos servicios de transmisión muestran patrones en los que los contratos activos tienen un mayor acceso a estos servicios en comparación con los contratos inactivos. Por lo tanto, los servicios de entretenimiento pueden influir positivamente en la retención de clientes.
# - **paperless_billing:** La facturación electrónica parece ser más común entre los contratos activos e inactivos, aunque la diferencia es mucho mayor en los contratos inactivos.
# - **multiple_lines:** La presencia de líneas múltiples es menos común en los contratos activos en comparación con los inactivos, donde la proporción es casi equilibrada.
# - **internet_service:** La fibra óptica es menos frecuente en los contratos activos en comparación con DSL. Existe una proporción considerable de contratos inactivos que utilizan fibra óptica en comparación con DSL, lo que podría estar relacionado con cancelaciones de contratos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - ¡Análisis bien estructurado! Has identificado patrones clave en el uso de servicios de Internet y su impacto en la retención de clientes. La combinación de visualización y observaciones detalladas refuerza el valor del análisis. ¡Sigue aplicando este enfoque riguroso en las siguientes etapas del proyecto! 🚀</div>

# %% [markdown]
# ### 3.2.9 ¿Cuáles son las características del cliente?
# - Para entender los patrones de comportamiento de los usuarios que cancelan sus contratos y de aquellos que mantienen contratos activos, examinaremos a continuación cada una de sus características.

# %%
# Categorías
categories = ['gender', 'senior_citizen', 'partner', 'dependents']

# Paleta de colores
custom_palette = {'No': 'gray', 'Yes': 'lightgreen', 0: 'gray',
                  1: 'lightgreen', 'Male': 'skyblue', 'Female': 'pink'}

# Tamaño del gráfico
plt.figure(figsize=(14, 13))

# Bucle
for i, category in enumerate(categories, 1):
    # Subtrama de contratos activos
    plt.subplot(len(categories), 2, 2*i - 1)
    ax = sns.countplot(x=category, data=active_contracts,
                       # Asegúrar de que el orden sea el mismo
                       order=sorted(active_contracts[category].unique()),
                       hue=category, palette=custom_palette)

    # Título
    plt.title(f'Active Contracts - {category}')
    plt.xlabel(category)
    plt.ylabel('Quantity')

    # Contar anotaciones
    for p in ax.patches:
        if p.get_height() > 0:
            ax.annotate(format(p.get_height(), '.0f'),
                        (p.get_x() + p.get_width() / 2., p.get_height()),
                        ha='center', va='center', xytext=(0, -15),
                        textcoords='offset points', fontsize=12)

    # Subtrama de contratos inactivos
    plt.subplot(len(categories), 2, 2*i)
    ax = sns.countplot(x=category, data=finished_contracts,
                       # Asegúrar de que el orden sea el mismo
                       order=sorted(finished_contracts[category].unique()),
                       hue=category, palette=custom_palette)

    # Título
    plt.title(f'Inactive Contracts - {category}')
    plt.xlabel(category)
    plt.ylabel('Quantity')

    # Contar anotaciones
    for p in ax.patches:
        if p.get_height() > 0:
            ax.annotate(format(p.get_height(), '.0f'),
                        (p.get_x() + p.get_width() / 2., p.get_height()),
                        ha='center', va='center', xytext=(0, -15),
                        textcoords='offset points', fontsize=12)

# Imprimir
plt.tight_layout()
plt.show()

# %% [markdown]
# - **gender:** No existe una diferencia significativa en cuanto a género entre los contratos activos e inactivos.
# - **senior_citizen:** Los mayores de edad tienen una menor proporción tanto en los contratos activos como en los inactivos. Sin embargo, a pesar de seguir siendo una minoría, la proporción de mayores de edad parece ser ligeramente superior entre los contratos activos.
# - **partner:** Los clientes que tienen pareja suelen tener una mayor proporción de contratos activos en comparación con los que no tienen pareja, lo que podría incidir positivamente en la retención de los contratos activos.
# - **dependents:** Aunque los clientes con dependientes son minoría en ambos casos, estos usuarios tienen una mayor proporción en los contratos activos en comparación con los contratos inactivos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Buen uso de visualizaciones para analizar el perfil del cliente. Identificaste correctamente factores que podrían influir en la retención. ¡Buen trabajo! 📊✅</div>

# %% [markdown]
# ### 3.2.10 ¿Qué tipos de contratos y cargos existen?
# - De acuerdo con los datos sobre tipos de contratos y cargos mensuales para contratos activos e inactivos, podemos identificar algunos patrones y características como los siguientes:

# %%
# Tipo de contrato
order = ['Month-to-month', 'One year', 'Two year']

# Tamaño del gráfico
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(18, 10))

# Subtrama 1: Cargos mensuales y contratos activos
sns.boxplot(x='type', y='monthly_charges', data=active_contracts,
            palette='Set3', hue='type', ax=axs[0, 0], order=order)
axs[0, 0].set_title('Cargos mensuales por contratos activos')
axs[0, 0].set_xlabel('Tipo de contrato')
axs[0, 0].set_ylabel('Cargos mensuales')

# Subtrama 2: Cargos mensuales y contratos inactivos
sns.boxplot(x='type', y='monthly_charges', data=finished_contracts,
            palette='Set3', hue='type', ax=axs[0, 1], order=order)
axs[0, 1].set_title('Cargos mensuales por contratos inactivos')
axs[0, 1].set_xlabel('Tipo de contrato')
axs[0, 1].set_ylabel('Cargos mensuales')

# Subtrama 3: Tipo de contrato y contratos activos
sns.countplot(x='type', data=active_contracts,
              palette='Set2', hue='type', ax=axs[1, 0], order=order)
axs[1, 0].set_title('Distribución de tipos de contratos para contratos activos')
axs[1, 0].set_xlabel('Tipo de contrato')
axs[1, 0].set_ylabel('Cantidad')

# Subtrama 4: Tipo de contrato y contratos inactivos
sns.countplot(x='type', data=finished_contracts,
              palette='Set2', hue='type', ax=axs[1, 1], order=order)
axs[1, 1].set_title('Distribución de tipos de contratos para contratos inactivos')
axs[1, 1].set_xlabel('Tipo de contrato')
axs[1, 1].set_ylabel('Cantidad')

# Imprimir
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Cargos mensuales por tipo de contrato
# - **Month-to-Month:** Estos contratos tienden a tener cargos mensuales más bajos para los contratos inactivos.
# - **Two Year:** En particular, para los contratos inactivos, se observa una mediana de cargos mensuales más alta, mientras que el rango intercuartil es mayor para los contratos activos. Se observa que los clientes que optan por cancelar su contrato tienen tarifas más altas, mientras que los usuarios con contratos que permanecen prefieren tarifas mensuales más accesibles y son menos propensos a cancelar.
# ##### Distribución del tipo de contrato
# - **Active Contracts:** “Month-to-Month” es el tipo de contrato más común entre los contratos activos; Esto sugiere que la mayoría de los clientes prefieren los contratos mensuales y, por tanto, la flexibilidad, en lugar de compromisos a largo plazo.
# - **Inactive Contracts:** El contrato “mes a mes” es también el tipo de contrato más común entre los contratos inactivos. La proporción de clientes que cancelan con un esquema de contrato “un año” o “dos años” es considerablemente menor en comparación con la proporción de estos mismos esquemas en los contratos activos.
# - **Resumen:** la mayoría de los clientes buscan contratos "Month-to-Month", lo que representa flexibilidad y en consecuencia una alta tasa de abandono o cancelación. En cambio, los clientes con contratos de “Un año” o “Dos años” generalmente buscan una afiliación a largo plazo ya que tienen una tasa de cancelación mínima.

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br> <b>Éxito</b> - ¡Muy buen trabajo en el análisis de los servicios de internet y características de los clientes! La combinación de gráficos y explicaciones detalladas permite obtener información valiosa sobre los factores que pueden influir en la cancelación de contratos. Además, la diferenciación entre contratos activos e inactivos es clave para identificar patrones relevantes. Sigue aplicando este nivel de detalle en el resto del análisis. 🚀📊</div>

# %% [markdown]
# ### 3.2.11 ¿Cuáles son los métodos de pago?
# - En base a la distribución de los métodos de pago para los contratos activos e inactivos, podemos observar lo siguiente:

# %%
# Definir el orden de los métodos de pago
payment_order = df_merged['payment_method'].value_counts().index

# Tamaño del gráfico y configuración del grid
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(14, 5))

# Subplot 1: Métodos de pago para contratos activos
sns.countplot(x='payment_method', data=active_contracts,
              palette='Set2', hue='payment_method', ax=axs[0], order=payment_order)
axs[0].set_title('Métodos de pago para contratos activos')
axs[0].set_xlabel('Método de pago')
axs[0].set_ylabel('Cantidad')

# Girar etiquetas del eje x
axs[0].tick_params(axis='x', rotation=45)

# Anotaciones en el countplot de contratos activos
for p in axs[0].patches:
    axs[0].annotate(format(p.get_height(), '.0f'),
                    (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center', xytext=(0, -10),
                    textcoords='offset points', fontsize=12)

# Subplot 2: Métodos de pago para contratos no activos
sns.countplot(x='payment_method', data=finished_contracts,
              palette='Set2', hue='payment_method', ax=axs[1], order=payment_order)
axs[1].set_title('Métodos de pago para contratos inactivos')
axs[1].set_xlabel('Método de pago')
axs[1].set_ylabel('Cantidad')


# Girar etiquetas del eje x
axs[1].tick_params(axis='x', rotation=45)

# Anotaciones en el countplot de contratos no activos
for p in axs[1].patches:
    axs[1].annotate(format(p.get_height(), '.0f'),
                    (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center', xytext=(0, -10),
                    textcoords='offset points', fontsize=12)

# Ajuste de diseño y mostrar
plt.tight_layout()
plt.show()

# %% [markdown]
# - **Balance de Contratos Activos:** Presentan una distribución bastante uniforme entre los cuatro métodos de pago, con un total de entre 1286 y 1304 contratos cada uno.
# - **Desbalance de Contratos Inactivos:** Presentan una marcada preferencia por el pago con cheque electrónico (1071 contratos), lo que sugiere que los clientes que utilizan este método de pago tienen una mayor tendencia a cancelar sus contratos.

# %% [markdown]
# ### Próximos pasos
# 1. Preparación de los datos
# - Eliminación de datos irrelevantes
# - Escalado de datos
# - Codificación de variables
# - División de datos
# - Equilibrio de clases
# - Sobremuestreo
# - Submuestreo
# 2. Análisis del rendimiento de diferentes modelos
# - Evaluación de modelos
# - Análisis de resultados
# - Selección del modelo con mejor rendimiento
# - Análisis del modelo con mejor rendimiento
# 3. Conclusiones

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br> <b>Éxito</b> - ¡Muy bien! La exploración de los métodos de pago aporta información clave para entender el comportamiento de cancelación. Has identificado correctamente que el uso de cheques electrónicos está asociado con una mayor tasa de cancelación, lo cual puede ser un punto de interés para la empresa. También es excelente que hayas definido los próximos pasos de forma clara y estructurada. ¡Sigue así! 🚀📊</div>

# %% [markdown]
# # Comentario general del revisor

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# ¡Felicidades Bo Torp! 🎉 Has realizado un análisis muy sólido y bien estructurado de los datos de contratos y cancelaciones. A lo largo del proyecto, demostraste habilidades clave en la limpieza, exploración y visualización de datos, lo que permitió extraer información relevante sobre los factores que influyen en la retención de clientes.
#
# **Puntos Positivos:**
# Exploración detallada: Realizaste un EDA completo, explorando múltiples factores como la duración de los contratos, los métodos de pago y los servicios contratados.
#
# Visualización efectiva: Los gráficos son claros y bien diseñados, facilitando la interpretación de las tendencias y patrones.
#
# Identificación de patrones clave: Destacaste correctamente la relación entre ciertos servicios y la retención de clientes, así como la correlación entre métodos de pago y cancelaciones. **Estructura organizada:** La división por secciones y las observaciones al final de cada análisis ayudan a seguir el razonamiento de manera clara.
#
# **Áreas para Seguir Investigando:**
# Modelado predictivo: Como mencionaste en tus próximos pasos, probar diferentes modelos de clasificación podría ser clave para predecir cancelaciones y tomar decisiones estratégicas.
#
# Feature engineering: Explorar nuevas variables derivadas (como la interacción entre múltiples servicios o cambios en el comportamiento del cliente) podría mejorar el rendimiento de los modelos.
#
# Balance de clases: Si la cancelación es una clase minoritaria, técnicas como el sobremuestreo (SMOTE) o el submuestreo pueden ayudar a mejorar la predicción.
#
# Análisis de correlación: Un análisis más profundo de la correlación entre variables podría ayudar a descartar información redundante antes del modelado.
#
# ¡Gran trabajo! Sigue avanzando y aplicando estas buenas prácticas en futuros proyectos. 🚀📊🔥
# </div>

# %% [markdown]
# ***
# ## 4. Preparación de datos <a id='prep'></a>

# %% [markdown]
# ### 4.1 Eliminación de datos irrelevantes <a id='elim'></a>
# Con base en todo el análisis anterior, se puede observar que las siguientes Series no son significativamente relevantes y por lo tanto se pueden omitir para simplificar el procesamiento:
# - <code style="background:grey;color:black">gender</code>: no hay una diferencia significativa en términos de género entre los contratos activos e inactivos.
# - <code style="background:grey;color:black">begin_date</code>: las fechas, por sí mismas, no son útiles como entradas directas para la mayoría de los modelos de aprendizaje automático. Es importante simplificar el conjunto de datos a las características más significativas.
# - <code style="background:grey;color:black">end_date</code>: similar a "begindate", estos datos ya no serán útiles. La nueva característica de destino "contract_active" (booleano) ayudará a simplificar los resultados de esta investigación.
# - <code style="background:grey;color:black">duration_days</code>: extraído de "begindate" y "enddate" fue útil en el análisis de datos exploratorios, pero no se identificaron patrones temporales específicos que pudieran influir en los resultados de esta investigación.
#  <code style="background:grey;color:black">customer_id</code>: inicialmente útil para fusionar todos los conjuntos de datos, pero generalmente no se usa como una característica en modelos predictivos directamente, por lo que es mejor eliminarlo.
# - <code style="background:grey;color:black">service_status</code>: Esta columna ya no es necesaria desde que creé la columna active_contract.

# %%
# Eliminar columnas
df_merged.drop(columns=['gender'], inplace=True)
df_merged.drop(columns=['begin_date'], inplace=True)
df_merged.drop(columns=['end_date'], inplace=True)
df_merged.drop(columns=['customer_id'], inplace=True)
df_merged.drop(columns=['duration_days'], inplace=True)
df_merged.drop(columns=['service_status'], inplace=True)

# %%
# Propiedades de DataFrame
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 0 to 7042
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   type               7032 non-null   object
#  1   paperless_billing  7032 non-null   object
#  2   payment_method     7032 non-null   object
#  3   monthly_charges    7032 non-null   float64
#  4   total_charges      7032 non-null   float64
#  5   senior_citizen     7032 non-null   int64
#  6   partner            7032 non-null   object
#  7   dependents         7032 non-null   object
#  8   internet_service   5512 non-null   object
#  9   online_security    5512 non-null   object
#  10  online_backup      5512 non-null   object
#  11  device_protection  5512 non-null   object
#  12  tech_support       5512 non-null   object
#  13  streaming_tv       5512 non-null   object
#  14  streaming_movies   5512 non-null   object
#  15  multiple_lines     6352 non-null   object
# ...

# %%
# Estadísticas descriptivas
df_merged.describe()
# Out:
#        monthly_charges  total_charges  senior_citizen
# count      7032.000000    7032.000000     7032.000000
# mean         64.798208    2283.300441        0.162400
# std          30.085974    2266.771362        0.368844
# min          18.250000      18.800000        0.000000
# 25%          35.587500     401.450000        0.000000
# 50%          70.350000    1397.475000        0.000000
# 75%          89.862500    3794.737500        0.000000
# max         118.750000    8684.800000        1.000000

# %% [markdown]
# ### 4.2 Escalado de datos <a id='esca'></a>
#
# - La técnica de escalado de datos se utiliza comúnmente en el preprocesamiento de datos para llevar todas las características a la misma escala.
# - A continuación, se escalan las características <code style="background:grey;color:black">monthly_charges</code> y "cargos totales" <code style="background:grey;color:black">total_charges</code> del conjunto de datos para normalizarlas.

# %%
# Inicializador
escalador = MinMaxScaler()

# Transformación
df_merged[['monthly_charges', 'total_charges']] = escalador.fit_transform(
    df_merged[['monthly_charges', 'total_charges']])

# %%
# Imprimir Columnas
display(df_merged[['monthly_charges', 'total_charges']])

# Estadísticas descriptivas
df_merged.describe()
# Out:
#       monthly_charges  total_charges
# 0            0.471144       0.066294
# 1            0.414428       0.060420
# 2            0.553731       0.030239
# 3            0.793532       0.140670
# 4            0.653234       0.028687
# ...               ...            ...
# 7038         0.367164       0.083556
# 7039         0.665174       0.214043
# 7040         0.318905       0.008533
# 7041         0.493532       0.531831
# 7042         0.405473       0.425664
#
# [7032 rows x 2 columns]
#        monthly_charges  total_charges  senior_citizen
# count      7032.000000    7032.000000     7032.000000
# mean          0.463166       0.261309        0.162400
# std           0.299363       0.261571        0.368844
# min           0.000000       0.000000        0.000000
# 25%           0.172512       0.044155        0.000000
# 50%           0.518408       0.159090        0.000000
# 75%           0.712562       0.435719        0.000000
# max           1.000000       1.000000        1.000000

# %% [markdown]
# ### 4.3 Codificación de variables <a id='codi'></a>
# #### OHE: One-Hot Encoding
# - Es esencial para el preprocesamiento de datos en el aprendizaje automático, facilitando la representación y el manejo de variables categóricas en modelos predictivos y analíticos.

# %%
# Columnas
columns_to_encode = ['internet_service', 'online_security', 'online_backup', 'device_protection',
                     'tech_support', 'streaming_tv', 'streaming_movies',
                     'senior_citizen', 'partner', 'dependents', 'paperless_billing', 'multiple_lines']

# Codifique 'type' y 'payment_method' sin eliminar ninguna columna
df_encoded = pd.get_dummies(df_merged, columns=['type', 'payment_method'])

# Codificar aquellos con dos valores únicos
df_encoded = pd.get_dummies(
    df_encoded, columns=columns_to_encode, drop_first=True)

# %%
# Propiedades de DataFrame
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   monthly_charges                           7032 non-null   float64
#  1   total_charges                             7032 non-null   float64
#  2   active_contract                           7032 non-null   bool
#  3   type_Month-to-month                       7032 non-null   bool
#  4   type_One year                             7032 non-null   bool
#  5   type_Two year                             7032 non-null   bool
#  6   payment_method_Bank transfer (automatic)  7032 non-null   bool
#  7   payment_method_Credit card (automatic)    7032 non-null   bool
#  8   payment_method_Electronic check           7032 non-null   bool
#  9   payment_method_Mailed check               7032 non-null   bool
# ...

# %%
# Mostrar DataFrame
df_encoded.head(5)
# Out:
#    monthly_charges  total_charges  active_contract  type_Month-to-month  \
# 0         0.471144       0.066294             True                False
# 1         0.414428       0.060420             True                 True
# 2         0.553731       0.030239            False                 True
# 3         0.793532       0.140670            False                 True
# 4         0.653234       0.028687            False                 True
#
#    type_One year  type_Two year  payment_method_Bank transfer (automatic)  \
# 0           True          False                                     False
# 1          False          False                                     False
# 2          False          False                                     False
# 3          False          False                                     False
# 4          False          False                                     False
#
#    payment_method_Credit card (automatic)  payment_method_Electronic check  \
# ...

# %% [markdown]
# ### 4.4 División de datos <a id='divi'></a>
# Los datos se dividen de la siguiente manera para lograr una proporción de 6:2:2:
# - **60 % Conjunto de datos de entrenamiento**
# - **20 % Conjunto de datos de validación**
# - **20 % Conjunto de datos de prueba**
#
# Cuanto mayor sea el conjunto de entrenamiento, más datos tendrá el modelo para aprender patrones y relaciones. El conjunto de datos de validación se utilizará para evaluar el rendimiento del modelo y el conjunto de datos de prueba se reservará hasta el final para evaluar el rendimiento final del modelo (una vez que se completen los procesos de entrenamiento y validación)

# %%
# Data split
df_train, remaining_data = train_test_split(df_encoded, test_size=0.4, random_state=12345)
df_valid, df_test = train_test_split(remaining_data, test_size=0.5, random_state=12345)

# %%
# Features and Target variables
features_train = df_train.drop(['active_contract'], axis=1)
target_train = df_train['active_contract']

features_valid = df_valid.drop(['active_contract'], axis=1)
target_valid = df_valid['active_contract']

# FINAL TESTING SETS ↓

# Train + Valid
total_features_train = pd.concat([features_train, features_valid])
total_target_train = pd.concat([target_train, target_valid])

features_test = df_test.drop(['active_contract'], axis=1)
target_test = df_test['active_contract']

print('Tamaño de la muestra de entrenamiento:', features_train.shape[0])
print('Tamaño de la muestra de validación:', features_valid.shape[0])
print('Tamaño de la muestra de prueba:', features_test.shape[0])
# Out:
# Tamaño de la muestra de entrenamiento: 4219
# Tamaño de la muestra de validación: 1406
# Tamaño de la muestra de prueba: 1407

# %% [markdown]
# ### 4.5 Equilibrio de clases <a id='equi'></a>
# El análisis del desequilibrio de clases se centra en las etiquetas de la variable de destino 'contract_active' (boolean) para comprender la proporción de cada clase ('True' o 'False'). Este análisis ayuda a determinar si existe un desequilibrio significativo en las clases, lo que es crucial para decidir si necesitamos aplicar técnicas de equilibrio como el submuestreo o el sobremuestreo.

# %%
# Calcular proporción
class_counts_train = target_train.value_counts(normalize=True)
print("Distribución de clases en el conjunto de entrenamiento:")
print(class_counts_train)

# Tamaño del gráfico
plt.figure(figsize=(4, 3))

# Datos de entrenamiento
plt.bar(class_counts_train.index, class_counts_train.values, color=['gray', 'lightgreen'])

# Título
plt.title('Class Distribution in the Training Set')
plt.xlabel('Class')
plt.ylabel('Proportion')
plt.xticks([0, 1], ['False', 'True'])

# Imprimir
plt.tight_layout()
plt.show()
# Out:
# Distribución de clases en el conjunto de entrenamiento:
# active_contract
# True     0.736193
# False    0.263807
# Name: proportion, dtype: float64

# %% [markdown]
# - El **sobremuestreo** y el **submuestreo** son dos técnicas comunes para abordar el desequilibrio de clases en un conjunto de datos.
# - A continuación se muestra el procedimiento para ambos métodos, ya que cada uno tiene sus beneficios y áreas de oportunidad. Las muestras resultantes serán clave para validar qué método respalda mejor el rendimiento del modelo para este proyecto específico.
# - Esto se realiza solo en el conjunto de entrenamiento y no es necesario aplicarlo a los conjuntos de validación y prueba, ya que estos conjuntos se utilizan principalmente para evaluar el rendimiento del modelo después de que se haya entrenado.

# %% [markdown]
# #### 4.4.1 Sobremuestreo
# - Implica aumentar la cantidad de ejemplos en la clase minoritaria para que coincida con la cantidad de ejemplos en la clase mayoritaria.
# - Este método no produce pérdida de datos; puede ser útil cuando hay suficiente tiempo de procesamiento y cuando la clase minoritaria contiene información valiosa que podría perderse con un submuestreo.
# - Por otro lado, puede generar tiempos de entrenamiento más prolongados y aumentar el riesgo de sobreajuste.

# %%
# Función
def upsample(features, target):
    features_zeros = features[target == False]
    features_ones = features[target == True]
    target_zeros = target[target == False]
    target_ones = target[target == True]

    # Número de repeticiones
    repeat_times = len(target_zeros) // len(target_ones)

    # Muestras adicionales
    additional_samples = len(target_zeros) % len(target_ones)

    # Aumentar la muestra de la clase minoritaria
    features_upsampled = pd.concat([features_zeros] + [features_ones] * repeat_times + [
                                   features_ones.sample(additional_samples, replace=True)])
    target_upsampled = pd.concat([target_zeros] + [target_ones] * repeat_times + [
                                 target_ones.sample(additional_samples, replace=True)])

    # Mezclar datos
    features_upsampled, target_upsampled = shuffle(
        features_upsampled, target_upsampled, random_state=12345)

    # Devolver
    return features_upsampled, target_upsampled

# Aplicar sobremuestreo
features_upsampled, target_upsampled = upsample(features_train, target_train)

# %%
# Calcular distribución
class_frequency_upsampled = target_upsampled.value_counts(normalize=True)

# Imprimir
print("Class distribution after oversampling:")
print(class_frequency_upsampled)

# Tamaño del gráfico
plt.figure(figsize=(4, 3))

# Gráfico
class_frequency_upsampled.plot(kind='bar', color=['gray', 'lightgreen'])

# Título
plt.title('Class Distribution After Oversampling')
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.xticks([0, 1], ['False', 'True'])

# Imprimir
plt.show()
# Out:
# Class distribution after oversampling:
# active_contract
# False    0.5
# True     0.5
# Name: proportion, dtype: float64

# %% [markdown]
# #### 4.4.2 Submuestreo
# - Implica reducir la cantidad de ejemplos en la clase mayoritaria para que coincida con la cantidad de ejemplos en la clase minoritaria.
# - Al reducir el tamaño del conjunto de datos, se puede acelerar el entrenamiento del modelo y mejorar el rendimiento al evitar el sobreajuste a la clase mayoritaria.
# - Por otro lado, se puede perder información valiosa al eliminar ejemplos de la clase mayoritaria, lo que potencialmente da como resultado un modelo menos preciso.

# %%
# Función
def downsample(features, target):

    # Separar características
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]

   
    # Submuestrear la clase mayoritaria (1)
    features_majority_downsampled = features_ones.sample(
        len(target_zeros), random_state=12345, replace=False)
    target_majority_downsampled = target_ones.sample(
        len(target_zeros), random_state=12345, replace=False)
    features_minority = features_zeros
    target_minority = target_zeros

    # Submuestrear la clase mayoritaria
    features_downsampled = pd.concat(
        [features_majority_downsampled, features_minority])
    target_downsampled = pd.concat(
        [target_majority_downsampled, target_minority])

    # Mezclar datos
    features_downsampled, target_downsampled = shuffle(
        features_downsampled, target_downsampled, random_state=12345)

    # Devolver
    return features_downsampled, target_downsampled


# Aplicar reducción de muestreo
features_downsampled, target_downsampled = downsample(
    features_train, target_train)

# %%
# Calcular distribución
class_frequency_downsampled = target_downsampled.value_counts(normalize=True)

# Imprimir
print("Class distribution after undersampling:")
print(class_frequency_downsampled)

# Tamaño del gráfico
plt.figure(figsize=(4, 3))

# Gráfico
plt.bar(class_frequency_downsampled.index.astype(str),
        class_frequency_downsampled.values, color=['gray', 'lightgreen'])

# Título
plt.title('Class Distribution After Undersampling')
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.xticks([0, 1], ['False', 'True'])

# Imprimir
plt.tight_layout()
plt.show()
# Out:
# Class distribution after undersampling:
# active_contract
# True     0.5
# False    0.5
# Name: proportion, dtype: float64

# %% [markdown]
# [Volver a Contenidos](#back)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Excelente trabajo en la preparación de datos. Has implementado una limpieza efectiva, aplicado técnicas de escalado y codificación adecuadas, y abordado correctamente el desequilibrio de clases con sobremuestreo y submuestreo. Este enfoque garantizará un mejor rendimiento del modelo y una evaluación justa. ¡Sigue así!
# </div>

# %% [markdown]
# ***
# ## 5. Desarrollo de modelos <a id='mod0'></a>
# **Introducción**
# Modelos
# Los datos están listos para comenzar a implementar los modelos para este proyecto de clasificación:
# - **Regresión logística**
# - **Clasificador KNN**
# - **Bosque aleatorio** *
# - **Máquina de refuerzo de gradiente (GBM)** *
# - **XGBoost (Extreme Gradient Boosting)** *
# - **LightGBM (Light Gradient Boosting Machine)** *
#
# (*) Incluye variación con validación cruzada para verificar la mejora del rendimiento.
#
# Nota: También se evaluará si los modelos funcionan mejor con los conjuntos de datos de submuestreo o sobremuestreo aplicados previamente.
#
# **Métricas**
# Para este proyecto de clasificación, los modelos se evaluarán utilizando las siguientes métricas:
# - **Exactitud:** calcula la proporción de predicciones correctas del total de predicciones realizadas.
# - **Precisión:** importante para evitar acciones de retención innecesarias para clientes que no cancelarían.
# - **Recordatorio:** crucial para identificar la mayor cantidad posible de clientes en riesgo.
# - **Puntuación F1:** proporciona un equilibrio entre precisión y recordatorio, lo cual es esencial para un modelo eficaz.
# - **Matriz de confusión:** ofrece una vista detallada del rendimiento del modelo, lo que permite identificar áreas de mejora.
# - **AUC-ROC:** proporciona una evaluación general del rendimiento del modelo, independientemente del umbral de clasificación.

# %% [markdown]
# ### 5.1 Modelo 1: Regresión logística <a id='mod1'></a>
# Es un modelo estadístico simple que estima la probabilidad de ocurrencia de un evento binario. En este proyecto, puede ser útil para identificar rápidamente las características más influyentes en las cancelaciones de contratos.

# %%
# Modelo
model1 = LogisticRegression(random_state=12345, max_iter=1000)

# Fit
start_upsampled = time.time()
model1.fit(features_upsampled, target_upsampled)
end_upsampled = time.time()
fit_time_model1__upsampled = end_upsampled - start_upsampled
start_downsampled = time.time()
model1.fit(features_downsampled, target_downsampled)
end_downsampled = time.time()
fit_time_model1__downsampled = end_downsampled - start_downsampled

# Predicciones
m1_predictions_valid = model1.predict(features_valid)
m1_predictions_proba_valid = model1.predict_proba(features_valid)[:, 1]

# Print
print(f'Tiempo necesario para entrenar el modelo submuestreado: {fit_time_model1__upsampled}.')
print(f'Tiempo necesario para entrenar el modelo sobremuestreado: {fit_time_model1__downsampled}.')
# Out:
# Tiempo necesario para entrenar el modelo submuestreado: 0.02556633949279785.
# Tiempo necesario para entrenar el modelo sobremuestreado: 0.015000581741333008.

# %%
# Imprimir
m1_auc_roc = roc_auc_score(target_valid, m1_predictions_proba_valid)
m1_accuracy = accuracy_score(target_valid, m1_predictions_valid)
m1_precision = precision_score(target_valid, m1_predictions_valid)
m1_recall = recall_score(target_valid, m1_predictions_valid)
m1_f1 = f1_score(target_valid, m1_predictions_valid)
m1_conf_matrix = confusion_matrix(target_valid, m1_predictions_valid)

# Métricas de impresión
print("\n*****\nModel 1: Logistic Regression")
print(f"AUC-ROC: {m1_auc_roc:.2f}")
print(f"Accuracy: {m1_accuracy:.2f}")
print(f"Precision: {m1_precision:.2f}")
print(f"Recall: {m1_recall:.2f}")
print(f"F1 Score: {m1_f1:.2f}")

# Matriz de confusión de impresión
print("Confusion Matrix:")
print(m1_conf_matrix)
# Out:
# *****
# Model 1: Logistic Regression
# AUC-ROC: 0.83
# Accuracy: 0.74
# Precision: 0.90
# Recall: 0.72
# F1 Score: 0.80
# Confusion Matrix:
# [[285  82]
#  [289 750]]

# %%
# Definición general de gráfico
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6)) 

# Matriz de confusión
disp = ConfusionMatrixDisplay(confusion_matrix=m1_conf_matrix)
disp.plot(ax=ax1, cmap='Blues')
ax1.set_title("Matriz de confusión (Regresión logística))")
ax1.set_xlabel("Predicción")
ax1.set_ylabel("Actual")
tick_labels = ['Falso', 'Verdadero']
ax1.set_xticks(ticks=[0, 1], labels=tick_labels)
ax1.set_yticks(ticks=[0, 1], labels=tick_labels)

# Curva ROC
fpr, tpr, _ = roc_curve(target_valid, m1_predictions_proba_valid)
ax2.plot(fpr, tpr, label='Curva ROC (AUC-ROC=%0.4f)' % m1_auc_roc)
ax2.set_xlabel('Índice de falsos positivos')
ax2.set_ylabel('Índice de verdaderos positivos')
ax2.set_title('Curva ROC (Regresión logística)')
ax2.legend(loc='lower right')

# Imprimir
plt.tight_layout()
plt.show()

# %% [markdown]
# El conjunto de datos submuestreado es el mejor para este modelo de regresión logística en este proyecto, con una mejor combinación de métricas clave como precisión, recuperación, puntuación F1 y una matriz de confusión con menos falsos negativos.

# %% [markdown]
# ### 5.2 Modelo 2: Clasificador KNN <a id='mod2'></a>
# Este modelo clasifica a un cliente en función de las características de sus vecinos más cercanos en una medida de similitud. Es un modelo fácil de implementar y puede ser útil para encontrar patrones entre clientes con características similares.

# %%
# Modelo
model2 = KNeighborsClassifier()

# Entrenar
start_upsampled = time.time()
model2.fit(features_upsampled, target_upsampled)
end_upsampled = time.time()
fit_time_model2__upsampled = end_upsampled - start_upsampled
start_downsampled = time.time()
model2.fit(features_downsampled, target_downsampled)
end_downsampled = time.time()
fit_time_model2__downsampled = end_downsampled - start_downsampled

# Predicciones
m2_predictions_valid = model2.predict(features_valid)
m2_predictions_proba_valid = model2.predict_proba(features_valid)[:, 1]

# Imprimir
print(f'Tiempo necesario para entrenar el modelo submuestreado: {fit_time_model2__upsampled}.')
print(f'Tiempo necesario para entrenar el modelo sobremuestreado: {fit_time_model2__downsampled}.')
# Out:
# Tiempo necesario para entrenar el modelo submuestreado: 0.004008054733276367.
# Tiempo necesario para entrenar el modelo sobremuestreado: 0.002990245819091797.

# %%
# Métricas
m2_auc_roc = roc_auc_score(target_valid, m2_predictions_proba_valid)
m2_accuracy = accuracy_score(target_valid, m2_predictions_valid)
m2_precision = precision_score(target_valid, m2_predictions_valid)
m2_recall = recall_score(target_valid, m2_predictions_valid)
m2_f1 = f1_score(target_valid, m2_predictions_valid)
m2_conf_matrix = confusion_matrix(target_valid, m2_predictions_valid)

# Imprimir
print("\n*****\nModel 2: K-Nearest Neighbors (KNN) Classifier")
print(f"AUC-ROC: {m2_auc_roc:.2f}")
print(f"Accuracy: {m2_accuracy:.2f}")
print(f"Precision: {m2_precision:.2f}")
print(f"Recall: {m2_recall:.2f}")
print(f"F1 Score: {m2_f1:.2f}")

# Imprimir la Matriz de Confusión
print("Confusion Matrix:")
print(m2_conf_matrix)
# Out:
# *****
# Model 2: K-Nearest Neighbors (KNN) Classifier
# AUC-ROC: 0.79
# Accuracy: 0.71
# Precision: 0.91
# Recall: 0.67
# F1 Score: 0.77
# Confusion Matrix:
# [[295  72]
#  [341 698]]

# %%
# Definición de gráfico# Plot definition

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Matriz de confusión
disp = ConfusionMatrixDisplay(confusion_matrix=m2_conf_matrix)
disp.plot(ax=ax1, cmap='Blues')
ax1.set_title("Matriz de confusión (clasificador KNN)")
ax1.set_xlabel("Predicción")
ax1.set_ylabel("Actual")
tick_labels = ['Falso', 'Verdadero']
ax1.set_xticks(ticks=[0, 1], labels=tick_labels)
ax1.set_yticks(ticks=[0, 1], labels=tick_labels)

# Curva ROC
fpr, tpr, _ = roc_curve(target_valid, m2_predictions_proba_valid)
ax2.plot(fpr, tpr, label='Curva ROC (AUC-ROC=%0.4f)' % m2_auc_roc)
ax2.set_xlabel('Índice de falsos positivos')
ax2.set_ylabel('Índice de verdaderos positivos')
ax2.set_title('Curva ROC (Clasificador KNN)')
ax2.legend(loc='lower right')

# Imprimir
plt.tight_layout()
plt.show()

# %% [markdown]
# El conjunto de datos submuestreado es el mejor para este modelo de K vecinos más cercanos (KNN), ya que proporciona un AUC-ROC y un puntaje F1 ligeramente más altos, lo que indica una mejor discriminación entre clases y un mejor equilibrio entre precisión y recuperación en comparación con el conjunto de datos con muestreo aumentado.

# %% [markdown]
# ### 5.3 Modelo 3: Bosque aleatorio <a id='mod3'></a>
# Construye múltiples árboles de decisión y combina sus resultados para hacer una predicción final. Es robusto y su capacidad para manejar una gran cantidad de variables y descubrir interacciones entre ellas lo hace valioso para identificar patrones complejos en las cancelaciones de clientes.

# %%
# Modelo
model3 = RandomForestClassifier(
    random_state=12345, n_estimators=100, max_depth=10, min_samples_split=10)

# Fit
start_upsampled = time.time()
model3.fit(features_upsampled, target_upsampled)
end_upsampled = time.time()
fit_time_model3__upsampled = end_upsampled - start_upsampled
start_downsampled = time.time()
model3.fit(features_downsampled, target_downsampled)
end_downsampled = time.time()
fit_time_model3__downsampled = end_downsampled - start_downsampled

# Predicciones
m3_predictions_valid = model3.predict(features_valid)
m3_predictions_proba_valid = model3.predict_proba(features_valid)[:, 1]

# Imprimir
print(f'Tiempo necesario para entrenar el modelo submuestreado: {fit_time_model3__upsampled}.')
print(f'Tiempo necesario para entrenar el modelo sobremuestreado: {fit_time_model3__downsampled}.')
# Out:
# Tiempo necesario para entrenar el modelo submuestreado: 0.22816252708435059.
# Tiempo necesario para entrenar el modelo sobremuestreado: 0.22123003005981445.

# %%
# Métricas
m3_auc_roc = roc_auc_score(target_valid, m3_predictions_proba_valid)
m3_accuracy = accuracy_score(target_valid, m3_predictions_valid)
m3_precision = precision_score(target_valid, m3_predictions_valid)
m3_recall = recall_score(target_valid, m3_predictions_valid)
m3_f1 = f1_score(target_valid, m3_predictions_valid)
m3_conf_matrix = confusion_matrix(target_valid, m3_predictions_valid)

# Imprimir métricas
print("\n*****\nModel 3: Random Forest")
print(f"AUC-ROC: {m3_auc_roc:.2f}")
print(f"Accuracy: {m3_accuracy:.2f}")
print(f"Precision: {m3_precision:.2f}")
print(f"Recall: {m3_recall:.2f}")
print(f"F1 Score: {m3_f1:.2f}")

# Matriz de confusión de impresión
print("Confusion Matrix:")
print(m3_conf_matrix)
# Out:
# *****
# Model 3: Random Forest
# AUC-ROC: 0.84
# Accuracy: 0.74
# Precision: 0.91
# Recall: 0.72
# F1 Score: 0.80
# Confusion Matrix:
# [[296  71]
#  [293 746]]

# %%
# Definición de gráfico
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Matriz de confusión
disp_rf = ConfusionMatrixDisplay(confusion_matrix=m3_conf_matrix)
disp_rf.plot(ax=ax1, cmap='Blues')
ax1.set_title("Matriz de confusión (bosque aleatorio)")
ax1.set_xlabel("Predicción")
ax1.set_ylabel("Actual")
tick_labels = ['Falso', 'Verdadero']
ax1.set_xticks(ticks=[0, 1], labels=tick_labels)
ax1.set_yticks(ticks=[0, 1], labels=tick_labels)

# ROC Curve
fpr_rf, tpr_rf, _ = roc_curve(target_valid, m3_predictions_proba_valid)
ax2.plot(fpr_rf, tpr_rf, label='Curva ROC (AUC-ROC=%0.4f)' % m3_auc_roc)
ax2.set_xlabel('Índice de falsos positivos')
ax2.set_ylabel('Índice de verdaderos positivos')
ax2.set_title('Curva ROC (Random Forest)')
ax2.legend(loc='lower right')

# Print
plt.tight_layout()
plt.show()

# %% [markdown]
# El conjunto de datos submuestreado es el mejor para este modelo de bosque aleatorio. Aunque ambos conjuntos de datos tienen el mismo AUC-ROC, el conjunto de datos reducido ofrece mejores métricas en términos de precisión, recuperación y puntuación F1. Esto indica que el modelo es más equilibrado y eficaz.

# %% [markdown]
# ### 5.4 Modelo 4: Búsqueda en cuadrícula + Bosque aleatorio <a id='mod4'></a>
# La búsqueda en cuadrícula optimiza los hiperparámetros del Bosque aleatorio al buscar la combinación que produce el mejor rendimiento y precisión del modelo.

# %%
# Modelo
model4 = RandomForestClassifier(random_state=12345)

# Parámetros
m4_param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [10, 20, 30],
    'min_samples_leaf': [10, 20, 30]
}

# Configuración de búsqueda de cuadrícula
m4_grid_search = GridSearchCV(
    estimator=model4, param_grid=m4_param_grid, cv=5, scoring='f1')

# Entrenar
start_upsampled = time.time()
m4_grid_search.fit(features_upsampled, target_upsampled)
end_upsampled = time.time()
fit_time_model4__upsampled = end_upsampled - start_upsampled
start_downsampled = time.time()
m4_grid_search.fit(features_downsampled, target_downsampled)
end_downsampled = time.time()
fit_time_model4__downsampled = end_downsampled - start_downsampled

# Mejor modelo
m4_best_model = m4_grid_search.best_estimator_

# Predicciones
m4_predictions_valid = m4_best_model.predict(features_valid)
m4_predictions_proba_valid = m4_best_model.predict_proba(features_valid)[:, 1]

# Mejores hiperparámetros y puntuación
print(f'Tiempo necesario para entrenar el modelo submuestreado: {fit_time_model4__upsampled}.')
print(f'Tiempo necesario para entrenar el modelo sobremuestreado: {fit_time_model4__downsampled}.')
print("Best hyperparameters:", m4_grid_search.best_params_)
print("Best F1:", m4_grid_search.best_score_)
# Out:
# Tiempo necesario para entrenar el modelo submuestreado: 23.041633367538452.
# Tiempo necesario para entrenar el modelo sobremuestreado: 21.895349502563477.
# Best hyperparameters: {'max_depth': 20, 'min_samples_leaf': 10, 'n_estimators': 50}
# Best F1: 0.744217500163485

# %%
# Métricas
m4_auc_roc = roc_auc_score(target_valid, m4_predictions_proba_valid)
m4_accuracy = accuracy_score(target_valid, m4_predictions_valid)
m4_precision = precision_score(target_valid, m4_predictions_valid)
m4_recall = recall_score(target_valid, m4_predictions_valid)
m4_f1 = f1_score(target_valid, m4_predictions_valid)
m4_conf_matrix = confusion_matrix(target_valid, m4_predictions_valid)

# Imprimir
print("\n*****\nModel 4: Grid Search + Random Forest")
print(f"AUC-ROC: {m4_auc_roc:.2f}")
print(f"Accuracy: {m4_accuracy:.2f}")
print(f"Precision: {m4_precision:.2f}")
print(f"Recall: {m4_recall:.2f}")
print(f"F1 Score: {m4_f1:.2f}")

# Imprimir matriz de confusión
print("Confusion Matrix:")
print(m4_conf_matrix)
# Out:
# *****
# Model 4: Grid Search + Random Forest
# AUC-ROC: 0.84
# Accuracy: 0.73
# Precision: 0.92
# Recall: 0.70
# F1 Score: 0.79
# Confusion Matrix:
# [[303  64]
#  [315 724]]

# %%
# Definición de gráfico
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Matriz de confusión
disp = ConfusionMatrixDisplay(confusion_matrix=m4_conf_matrix)
disp.plot(ax=ax1, cmap='Blues')
ax1.set_title("Matriz de confusión (Búsqueda en cuadrícula + Bosque aleatorio)")
ax1.set_xlabel("Predicción")
ax1.set_ylabel("Actual")
tick_labels = ['Falso', 'Verdadero']
ax1.set_xticks(ticks=[0, 1], labels=tick_labels)
ax1.set_yticks(ticks=[0, 1], labels=tick_labels)

# ROC Curve
fpr, tpr, _ = roc_curve(target_valid, m4_predictions_proba_valid)
ax2.plot(fpr, tpr, label='Curva ROC (AUC-ROC=%0.4f)' % m4_auc_roc)
ax2.set_xlabel('Índice de falsos positivos')
ax2.set_ylabel('Índice de verdaderos positivos')
ax2.set_title('Curva ROC (Búsqueda en cuadrícula + Bosque aleatorio)')
ax2.legend(loc='lower right')

# Print
plt.tight_layout()
plt.show()

# %% [markdown]
# El conjunto de datos submuestreado es el mejor para este modelo de búsqueda en cuadrícula + bosque aleatorio. Muestra un rendimiento ligeramente mejor en términos de métricas clave como la puntuación F1 y la matriz de confusión.

# %% [markdown]
# ### 5.5 Modelo 5: Gradient Boosting Machine (GBM) <a id='mod5'></a>
# Modelo que construye árboles de decisión de forma secuencial, donde cada nuevo árbol intenta corregir los errores del anterior. Es potente y eficaz para encontrar patrones complejos en los datos, lo que podría ser clave para predecir con precisión las tasas de abandono de clientes.

# %%
# Modelo
model5 = GradientBoostingClassifier(random_state=12345)

# Entrenar
start_upsampled = time.time()
model5.fit(features_upsampled, target_upsampled)
end_upsampled = time.time()
fit_time_model5__upsampled = end_upsampled - start_upsampled
start_downsampled = time.time()
model5.fit(features_downsampled, target_downsampled)
end_downsampled = time.time()
fit_time_model5__downsampled = end_downsampled - start_downsampled

# Predicciones
m5_predictions_valid = model5.predict(features_valid)
m5_predictions_proba_valid = model5.predict_proba(features_valid)[:, 1]

# Imprimir
print(f'Tiempo necesario para entrenar el modelo submuestreado: {fit_time_model5__upsampled}.')
print(f'Tiempo necesario para entrenar el modelo sobremuestreado: {fit_time_model5__downsampled}.')
# Out:
# Tiempo necesario para entrenar el modelo submuestreado: 0.29885411262512207.
# Tiempo necesario para entrenar el modelo sobremuestreado: 0.29775452613830566.

# %%
# Métricas
m5_auc_roc = roc_auc_score(target_valid, m5_predictions_proba_valid)
m5_accuracy = accuracy_score(target_valid, m5_predictions_valid)
m5_precision = precision_score(target_valid, m5_predictions_valid)
m5_recall = recall_score(target_valid, m5_predictions_valid)
m5_f1 = f1_score(target_valid, m5_predictions_valid)
m5_conf_matrix = confusion_matrix(target_valid, m5_predictions_valid)

# Imprimir
print("\n*****\nModel 5: Gradient Boosting Machine (GBM)")
print(f"AUC-ROC: {m5_auc_roc:.2f}")
print(f"Accuracy: {m5_accuracy:.2f}")
print(f"Precision: {m5_precision:.2f}")
print(f"Recall: {m5_recall:.2f}")
print(f"F1 Score: {m5_f1:.2f}")

# Imprimir matriz de confusión
print("Confusion Matrix:")
print(m5_conf_matrix)
# Out:
# *****
# Model 5: Gradient Boosting Machine (GBM)
# AUC-ROC: 0.84
# Accuracy: 0.74
# Precision: 0.91
# Recall: 0.71
# F1 Score: 0.80
# Confusion Matrix:
# [[294  73]
#  [299 740]]

# %%
# Definición general de gráfico
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Confusion Matrix
disp = ConfusionMatrixDisplay(confusion_matrix=m5_conf_matrix)
disp.plot(ax=ax1, cmap='Blues')
ax1.set_title("Matriz de confusión (GBM)")
ax1.set_xlabel("Predicción")
ax1.set_ylabel("Actual")
tick_labels = ['Falso', 'Verdadero']
ax1.set_xticks(ticks=[0, 1], labels=tick_labels)
ax1.set_yticks(ticks=[0, 1], labels=tick_labels)

# ROC Curve
fpr, tpr, _ = roc_curve(target_valid, m5_predictions_proba_valid)
ax2.plot(fpr, tpr, label='Curva ROC (AUC-ROC=%0.4f)' % m5_auc_roc)
ax2.set_xlabel('Índice de falsos positivos')
ax2.set_ylabel('Índice de verdaderos positivos')
ax2.set_title('Curva ROC (GBM)')
ax2.legend(loc='lower right')

# Print
plt.tight_layout()
plt.show()

# %% [markdown]
# El conjunto de datos submuestreado es el mejor para este modelo de máquina de aumento de gradiente (GBM). Aunque el conjunto de datos aumentado tiene un AUC-ROC ligeramente mejor (0,86 frente a 0,85), el conjunto de datos reducido ofrece mejores métricas en términos de precisión, recuperación y puntuación F1.

# %% [markdown]
# ### 5.6 Modelo 6: Búsqueda en cuadrícula + Máquina de potenciación de gradiente (GBM) <a id='mod6'></a>
# La búsqueda en cuadrícula optimiza los hiperparámetros del modelo de potenciación de gradiente al buscar la combinación que maximiza el rendimiento.

# %%
# Modelo
model6 = GradientBoostingClassifier(random_state=12345)

# Parámetros
m6_param_grid = {
    'n_estimators': [50, 100, 150],
    'learning_rate': [0.01, 0.1],
    'max_depth': [3, 5, 7],
    'min_samples_leaf': [10, 20]
}

# Configuración de búsqueda de cuadrícula
m6_grid_search = GridSearchCV(
    estimator=model6, param_grid=m6_param_grid, cv=5, scoring='f1')

# Entrenar con búsqueda de cuadrícula
start_upsampled = time.time()
m6_grid_search.fit(features_upsampled, target_upsampled)
end_upsampled = time.time()
fit_time_model6__upsampled = end_upsampled - start_upsampled
start_downsampled = time.time()
m6_grid_search.fit(features_downsampled, target_downsampled)
end_downsampled = time.time()
fit_time_model6__downsampled = end_downsampled - start_downsampled


# Mejor modelo
m6_best_model = m6_grid_search.best_estimator_

# Predicciones
m6_predictions_valid = m6_best_model.predict(features_valid)
m6_predictions_proba_valid = m6_best_model.predict_proba(features_valid)[:, 1]

# Mejores hiperparámetros y puntuación
print(f'Tiempo necesario para entrenar el modelo submuestreado: {fit_time_model6__upsampled}.')
print(f'Tiempo necesario para entrenar el modelo sobremuestreado: {fit_time_model6__downsampled}.')
print("Best hyperparameters:", m6_grid_search.best_params_)
print("Best F1:", m6_grid_search.best_score_)
# Out:
# Tiempo necesario para entrenar el modelo submuestreado: 73.46614813804626.
# Tiempo necesario para entrenar el modelo sobremuestreado: 77.20483922958374.
# Best hyperparameters: {'learning_rate': 0.1, 'max_depth': 3, 'min_samples_leaf': 20, 'n_estimators': 50}
# Best F1: 0.7496416886605484

# %%
# Métricas
m6_auc_roc = roc_auc_score(target_valid, m6_predictions_proba_valid)
m6_accuracy = accuracy_score(target_valid, m6_predictions_valid)
m6_precision = precision_score(target_valid, m6_predictions_valid)
m6_recall = recall_score(target_valid, m6_predictions_valid)
m6_f1 = f1_score(target_valid, m6_predictions_valid)
m6_conf_matrix = confusion_matrix(target_valid, m6_predictions_valid)

# Imprimir
print("\n*****\nModel 6: Grid Search + Gradient Boosting Machine")
print(f"AUC-ROC: {m6_auc_roc:.2f}")
print(f"Accuracy: {m6_accuracy:.2f}")
print(f"Precision: {m6_precision:.2f}")
print(f"Recall: {m6_recall:.2f}")
print(f"F1 Score: {m6_f1:.2f}")

# Imprimir matriz de confusión
print("Confusion Matrix:")
print(m6_conf_matrix)
# Out:
# *****
# Model 6: Grid Search + Gradient Boosting Machine
# AUC-ROC: 0.84
# Accuracy: 0.74
# Precision: 0.92
# Recall: 0.71
# F1 Score: 0.80
# Confusion Matrix:
# [[302  65]
#  [304 735]]

# %%
# Definición general de gráfico
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Matriz de confusión
disp = ConfusionMatrixDisplay(confusion_matrix=m6_conf_matrix)
disp.plot(ax=ax1, cmap='Blues')
ax1.set_title("Confusion Matrix (Grid Search + Gradient Boosting Machine)")
ax1.set_xlabel("Predicción")
ax1.set_ylabel("Actual")
tick_labels = ['Falso', 'Verdadero']
ax1.set_xticks(ticks=[0, 1], labels=tick_labels)
ax1.set_yticks(ticks=[0, 1], labels=tick_labels)

# Curva ROC
fpr, tpr, _ = roc_curve(target_valid, m6_predictions_proba_valid)
ax2.plot(fpr, tpr, label='Curva ROC (AUC-ROC=%0.4f)' % m6_auc_roc)
ax2.set_xlabel('Índice de falsos positivos')
ax2.set_ylabel('Índice de verdaderos positivos')
ax2.set_title('Curva ROC (Grid Search + Gradient Boosting Machine)')
ax2.legend(loc='lower right')

# Imprimir
plt.tight_layout()
plt.show()

# %% [markdown]
# El conjunto de datos submuestreado es el mejor para este modelo de búsqueda en cuadrícula + máquina de aumento de gradiente. Muestra métricas ligeramente superiores en términos de AUC-ROC, precisión y puntaje F1.

# %% [markdown]
# ### 5.7 Modelo 7: XGBoost (Extreme Gradient Boosting) <a id='mod7'></a>
# Una versión mejorada de Gradient Boosting que hace que el modelo sea más rápido y preciso. Es extremadamente eficaz para problemas como predecir la pérdida de clientes.

# %%
# Establezca el nivel de registro en ERROR para suprimir las advertencias ("use_label_encoder")
xgb.set_config(verbosity=2)
warnings.filterwarnings('ignore', category=UserWarning, module='xgboost')

# %%
# Convertir matrices de NumPy
features_downsampled_np = features_downsampled.values
target_downsampled_np = target_downsampled.values
features_upsampled_np = features_upsampled.values
target_upsampled_np = target_upsampled.values
features_valid_np = features_valid.values

# Modelo
model7 = xgb.XGBClassifier(random_state=12345)

# Entrenar
start_upsampled = time.time()
model7.fit(features_upsampled_np, target_upsampled_np)
end_upsampled = time.time()
fit_time_model7__upsampled = end_upsampled - start_upsampled
start_downsampled = time.time()
model7.fit(features_downsampled_np, target_downsampled_np)
end_downsampled = time.time()
fit_time_model7__downsampled = end_downsampled - start_downsampled

# Predicciones
m7_predictions_valid = model7.predict(features_valid_np)
m7_predictions_proba_valid = model7.predict_proba(features_valid_np)[:, 1]

# Imprimir
print(f'Tiempo necesario para entrenar el modelo submuestreado: {fit_time_model7__upsampled}.')
print(f'Tiempo necesario para entrenar el modelo sobremuestreado: {fit_time_model7__downsampled}.')
# Out:
# Tiempo necesario para entrenar el modelo submuestreado: 0.08176302909851074.
# Tiempo necesario para entrenar el modelo sobremuestreado: 0.04800128936767578.

# %%
# Métricas
m7_auc_roc = roc_auc_score(target_valid, m7_predictions_proba_valid)
m7_accuracy = accuracy_score(target_valid, m7_predictions_valid)
m7_precision = precision_score(target_valid, m7_predictions_valid)
m7_recall = recall_score(target_valid, m7_predictions_valid)
m7_f1 = f1_score(target_valid, m7_predictions_valid)
m7_conf_matrix = confusion_matrix(target_valid, m7_predictions_valid)

# Imprimir
print("\n*****\nModel 7: XGBoost (Extreme Gradient Boosting)")
print(f"AUC-ROC: {m7_auc_roc:.2f}")
print(f"Accuracy: {m7_accuracy:.2f}")
print(f"Precision: {m7_precision:.2f}")
print(f"Recall: {m7_recall:.2f}")
print(f"F1 Score: {m7_f1:.2f}")

# Imprimir matriz de confusión
print("Confusion Matrix:")
print(m7_conf_matrix)
# Out:
# *****
# Model 7: XGBoost (Extreme Gradient Boosting)
# AUC-ROC: 0.80
# Accuracy: 0.71
# Precision: 0.89
# Recall: 0.70
# F1 Score: 0.78
# Confusion Matrix:
# [[275  92]
#  [316 723]]

# %%
# Definición general de gráfico# General plot definition
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Matriz de confusión
disp = ConfusionMatrixDisplay(confusion_matrix=m7_conf_matrix)
disp.plot(ax=ax1, cmap='Blues')
ax1.set_title("Matriz de confusión (XGBoost)")
ax1.set_xlabel("Predicción")
ax1.set_ylabel("Actual")
tick_labels = ['Falso', 'Verdadero']
ax1.set_xticks(ticks=[0, 1], labels=tick_labels)
ax1.set_yticks(ticks=[0, 1], labels=tick_labels)

# Curva ROC
fpr, tpr, _ = roc_curve(target_valid, m7_predictions_proba_valid)
ax2.plot(fpr, tpr, label='Curva ROC (AUC-ROC=%0.4f)' % m7_auc_roc)
ax2.set_xlabel('Índice de falsos positivos')
ax2.set_ylabel('Índice de verdaderos positivos')
ax2.set_title('Curva ROC (XGBoost)')
ax2.legend(loc='lower right')

# Imprimir
plt.tight_layout()
plt.show()

# %% [markdown]
# El conjunto de datos submuestreado es el mejor para este modelo XGBoost. Aunque el conjunto de datos aumentado muestra un AUC-ROC ligeramente mejor (0,83 frente a 0,82) y una precisión ligeramente superior, el conjunto de datos reducido ofrece una mayor exactitud, recuperación, puntuación F1 y una mayor cantidad de verdaderos positivos.

# %% [markdown]
# ### 5.8 Modelo 8: Búsqueda en cuadrícula + XGBoost (Extreme Gradient Boosting) <a id='mod8'></a>
# La búsqueda en cuadrícula ajusta los hiperparámetros del modelo XGBoost para encontrar la configuración que proporcione el mejor rendimiento posible.

# %%
# Modelo
model8 = XGBClassifier(
    random_state=12345, use_label_encoder=False, eval_metric='logloss')

# Parámetros
m8_param_grid = {
    'n_estimators': [50, 100, 150],
    'learning_rate': [0.01, 0.1],
    'max_depth': [3, 5, 7],
    'min_child_weight': [1, 3, 5]
}

# Configuración de búsqueda de cuadrícula
m8_grid_search = GridSearchCV(
    estimator=model8, param_grid=m8_param_grid, cv=5, scoring='f1')

# Entrenar GridSearchCV
start_upsampled = time.time()
m8_grid_search.fit(features_upsampled_np, target_upsampled_np)
end_upsampled = time.time()
fit_time_model8__upsampled = end_upsampled - start_upsampled
start_downsampled = time.time()
m8_grid_search.fit(features_downsampled_np, target_downsampled_np)
end_downsampled = time.time()
fit_time_model8__downsampled = end_downsampled - start_downsampled

# Mejor modelo
m8_best_model = m8_grid_search.best_estimator_

# Predicciones
m8_predictions_valid = m8_best_model.predict(features_valid_np)
m8_predictions_proba_valid = m8_best_model.predict_proba(features_valid_np)[
    :, 1]

# Mejores hiperparámetros y puntuación
print(f'Tiempo necesario para entrenar el modelo submuestreado: {fit_time_model8__upsampled}.')
print(f'Tiempo necesario para entrenar el modelo sobremuestreado: {fit_time_model8__downsampled}.')
print("Best hyperparameters:", m8_grid_search.best_params_)
print("Best F1:", m8_grid_search.best_score_)
# Out:
# Tiempo necesario para entrenar el modelo submuestreado: 12.784987688064575.
# Tiempo necesario para entrenar el modelo sobremuestreado: 13.16109824180603.
# Best hyperparameters: {'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50}
# Best F1: 0.7518394976848767

# %%
# Métricas
m8_auc_roc = roc_auc_score(target_valid, m8_predictions_proba_valid)
m8_accuracy = accuracy_score(target_valid, m8_predictions_valid)
m8_precision = precision_score(target_valid, m8_predictions_valid)
m8_recall = recall_score(target_valid, m8_predictions_valid)
m8_f1 = f1_score(target_valid, m8_predictions_valid)
m8_conf_matrix = confusion_matrix(target_valid, m8_predictions_valid)

# Imprimir
print("\n*****\nModel 8: Grid Search + Extreme Gradient Boosting (XGBoost)")
print(f"AUC-ROC: {m8_auc_roc:.2f}")
print(f"Accuracy: {m8_accuracy:.2f}")
print(f"Precision: {m8_precision:.2f}")
print(f"Recall: {m8_recall:.2f}")
print(f"F1 Score: {m8_f1:.2f}")

# Matriz de confusión de impresión
print("Confusion Matrix")
print(m8_conf_matrix)
# Out:
# *****
# Model 8: Grid Search + Extreme Gradient Boosting (XGBoost)
# AUC-ROC: 0.84
# Accuracy: 0.73
# Precision: 0.92
# Recall: 0.69
# F1 Score: 0.79
# Confusion Matrix
# [[306  61]
#  [320 719]]

# %%
# Definición general de gráfico
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Matriz de confusión
disp = ConfusionMatrixDisplay(confusion_matrix=m8_conf_matrix)
disp.plot(ax=ax1, cmap='Blues')
ax1.set_title("Matriz de confusión (Grid Search + XGBoost)")
ax1.set_xlabel("Predicción")
ax1.set_ylabel("Actual")
tick_labels = ['Falso', 'Verdadero']
ax1.set_xticks(ticks=[0, 1], labels=tick_labels)
ax1.set_yticks(ticks=[0, 1], labels=tick_labels)

# Curva ROC
fpr, tpr, _ = roc_curve(target_valid, m8_predictions_proba_valid)
ax2.plot(fpr, tpr, label='Curva ROC (AUC-ROC=%0.4f)' % m8_auc_roc)
ax2.set_xlabel('Índice de falsos positivos')
ax2.set_ylabel('Índice de verdaderos positivos')
ax2.set_title('Curva ROC  (Grid Search + XGBoost)')
ax2.legend(loc='lower right')

# Imprimir
plt.tight_layout()
plt.show()

# %% [markdown]
# El conjunto de datos submuestreado es el mejor para este modelo de búsqueda en cuadrícula + XGBoost. Ofrece un mejor rendimiento en términos de precisión, recuperación y puntuación F1, lo que es crucial para lograr un equilibrio adecuado entre la identificación correcta de instancias positivas.

# %% [markdown]
# ### 5.9 Modelo 9: LightGBM <a id='mod9'></a>
# LightGBM es una variante de Gradient Boosting optimizada para la velocidad y la eficiencia de la memoria, capaz de manejar grandes volúmenes de datos. Su eficiencia y precisión lo hacen ideal para grandes conjuntos de datos.

# %%
# Model0
model9 = lgb.LGBMClassifier(random_state=12345)

# Entrenar
start_upsampled = time.time()
model9.fit(features_upsampled, target_upsampled)
end_upsampled = time.time()
fit_time_model9__upsampled = end_upsampled - start_upsampled
start_downsampled = time.time()
model9.fit(features_downsampled, target_downsampled)
end_downsampled = time.time()
fit_time_model9__downsampled = end_downsampled - start_downsampled

# Predicciones
m9_predictions_valid = model9.predict(features_valid)
m9_predictions_proba_valid = model9.predict_proba(features_valid)[:, 1]

# Imprimir
print(f'Tiempo necesario para entrenar el modelo submuestreado: {fit_time_model9__upsampled}.')
print(f'Tiempo necesario para entrenar el modelo sobremuestreado: {fit_time_model9__downsampled}.')
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 1113, number of negative: 1113
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001123 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 548
# [LightGBM] [Info] Number of data points in the train set: 2226, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 1113, number of negative: 1113
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000212 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# ...

# %%
# Métricas
m9_auc_roc = roc_auc_score(target_valid, m9_predictions_proba_valid)
m9_accuracy = accuracy_score(target_valid, m9_predictions_valid)
m9_precision = precision_score(target_valid, m9_predictions_valid)
m9_recall = recall_score(target_valid, m9_predictions_valid)
m9_f1 = f1_score(target_valid, m9_predictions_valid)
m9_conf_matrix = confusion_matrix(target_valid, m9_predictions_valid)

# Imprimir
print("\n*****\nModel 9: LightGBM (Light Gradient Boosting Machine)")
print(f"AUC-ROC: {m9_auc_roc:.2f}")
print(f"Accuracy: {m9_accuracy:.2f}")
print(f"Precision: {m9_precision:.2f}")
print(f"Recall: {m9_recall:.2f}")
print(f"F1 Score: {m9_f1:.2f}")

# Imprimir matriz de confusión
print("Confusion Matrix:")
print(m9_conf_matrix)
# Out:
# *****
# Model 9: LightGBM (Light Gradient Boosting Machine)
# AUC-ROC: 0.82
# Accuracy: 0.72
# Precision: 0.90
# Recall: 0.70
# F1 Score: 0.79
# Confusion Matrix:
# [[290  77]
#  [312 727]]

# %%
# Definición general de gráfico
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Matriz de confusión
disp = ConfusionMatrixDisplay(confusion_matrix=m9_conf_matrix)
disp.plot(ax=ax1, cmap='Blues')
ax1.set_title("Matriz de confusión (LightGBM)")
ax1.set_xlabel("Predicción")
ax1.set_ylabel("Actual")
tick_labels = ['Falso', 'Verdadero']
ax1.set_xticks(ticks=[0, 1], labels=tick_labels)
ax1.set_yticks(ticks=[0, 1], labels=tick_labels)

# Curva ROC
fpr, tpr, _ = roc_curve(target_valid, m9_predictions_proba_valid)
ax2.plot(fpr, tpr, label='Curva ROC (AUC-ROC=%0.4f)' % m9_auc_roc)
ax2.set_xlabel('Índice de falsos positivos')
ax2.set_ylabel('Índice de verdaderos positivos')
ax2.set_title('Curva ROC (LightGBM)')
ax2.legend(loc='lower right')

# Imprimir
plt.tight_layout()
plt.show()

# %% [markdown]
# El conjunto de datos submuestreado es el mejor para este modelo LightGBM. Aunque ambos conjuntos de datos tienen un AUC-ROC idéntico, el conjunto de datos reducido ofrece mejores resultados en términos de precisión general, recuperación y puntuación F1. Además, proporciona un mejor equilibrio entre verdaderos positivos y falsos negativos.

# %% [markdown]
# ### 5.10 Modelo 10: Búsqueda en cuadrícula + LightGBM <a id='mod10'></a>
# Optimizar LightGBM con búsqueda en cuadrícula puede hacer que el modelo alcance su máximo potencial, aumentando la precisión y maximizando el AUC-ROC.

# %%
# Modelo
model10 = lgb.LGBMClassifier(random_state=12345)

# Parámetros
m10_param_grid = {
    'num_leaves': [20, 31],
    'learning_rate': [0.01, 0.1],
    'n_estimators': [50, 100, 150],
    'max_depth': [5, 15]
}

# Configuración de búsqueda de cuadrícula
m10_grid_search = GridSearchCV(
    estimator=model10, param_grid=m10_param_grid, cv=5, scoring='f1')

# Entrenar
start_upsampled = time.time()
m10_grid_search.fit(features_upsampled, target_upsampled)
end_upsampled = time.time()
fit_time_model10__upsampled = end_upsampled - start_upsampled
start_downsampled = time.time()
m10_grid_search.fit(features_downsampled, target_downsampled)
end_downsampled = time.time()
fit_time_model10__downsampled = end_downsampled - start_downsampled

# Mejor modelo
m10_best_model = m10_grid_search.best_estimator_

# Predicciones
m10_predictions_valid = m10_best_model.predict(features_valid)
m10_predictions_proba_valid = m10_best_model.predict_proba(features_valid)[:, 1]

# Los mejores hiperparámetros
print(f'Tiempo necesario para entrenar el modelo submuestreado: {fit_time_model10__upsampled}.')
print(f'Tiempo necesario para entrenar el modelo sobremuestreado: {fit_time_model10__downsampled}.')
print(f"Best hyperparameters: {m10_grid_search.best_params_}")
print(f"Best F1: {m10_grid_search.best_score_:.2f}")
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 890, number of negative: 890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000297 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 548
# [LightGBM] [Info] Number of data points in the train set: 1780, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 891, number of negative: 890
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000325 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 548
# ...

# %%
# Métricas
m10_auc_roc = roc_auc_score(target_valid, m10_predictions_proba_valid)
m10_accuracy = accuracy_score(target_valid, m10_predictions_valid)
m10_precision = precision_score(target_valid, m10_predictions_valid)
m10_recall = recall_score(target_valid, m10_predictions_valid)
m10_f1 = f1_score(target_valid, m10_predictions_valid)
m10_conf_matrix = confusion_matrix(target_valid, m10_predictions_valid)

# Imprimir
print("\n*****\nModel 10: Grid Search + LightGBM")
print(f"AUC-ROC: {m10_auc_roc:.2f}")
print(f"Accuracy: {m10_accuracy:.2f}")
print(f"Precision: {m10_precision:.2f}")
print(f"Recall: {m10_recall:.2f}")
print(f"F1 Score: {m10_f1:.2f}")

# Matriz de confusión de impresión
print("Confusion Matrix:")
print(m10_conf_matrix)
# Out:
# *****
# Model 10: Grid Search + LightGBM
# AUC-ROC: 0.83
# Accuracy: 0.73
# Precision: 0.91
# Recall: 0.71
# F1 Score: 0.80
# Confusion Matrix:
# [[294  73]
#  [300 739]]

# %%
# Definición de gráfico
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Matriz de confusión
disp = ConfusionMatrixDisplay(confusion_matrix=m10_conf_matrix)
disp.plot(ax=ax1, cmap='Blues')
ax1.set_title("Matriz de confusión (Grid Search + LightGBM)")
ax1.set_xlabel("Predicción")
ax1.set_ylabel("Actual")
tick_labels = ['Falso', 'Verdadero']
ax1.set_xticks(ticks=[0, 1], labels=tick_labels)
ax1.set_yticks(ticks=[0, 1], labels=tick_labels)

# Curva ROC
fpr, tpr, _ = roc_curve(target_valid, m10_predictions_proba_valid)
ax2.plot(fpr, tpr, label='Curva ROC (AUC-ROC=%0.4f)' % m10_auc_roc)
ax2.set_xlabel('Índice de falsos positivos')
ax2.set_ylabel('Índice de verdaderos positivos')
ax2.set_title('Curva ROC (Grid Search + LightGBM)')
ax2.legend(loc='lower right')

# Imprimir
plt.tight_layout()
plt.show()

# %% [markdown]
# El conjunto de datos submuestreado es el mejor para este modelo Grid Search + LightGBM. Aunque ambos conjuntos de datos producen resultados similares, el modelo con el conjunto de datos reducido de la muestra tiene un mejor equilibrio en términos de recuperación y puntuación F1.

# %% [markdown]
# [Volver a Contenidos](#back)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Excelente trabajo en la implementación de modelos. Has probado una amplia variedad de enfoques, incluyendo técnicas avanzadas como optimización de hiperparámetros con búsqueda en cuadrícula y diferentes estrategias de muestreo. La evaluación con múltiples métricas y la comparación entre modelos es un punto fuerte de tu análisis. ¡Bien hecho!
# </div>

# %% [markdown]
# ***
# ## 6. Evaluación del modelo <a id='eva0'></a>
# ### Resumen de resultados
# Para presentar los resultados de una manera más estructurada y clara, la siguiente tabla permitirá una fácil comparación de las métricas entre los diferentes modelos. Además, se mostrarán visualmente las matrices de confusión de todos los modelos y, por último, se mostrará un gráfico con todas las curvas ROC de los modelos evaluados anteriormente.

# %%
# Diccionario
resultados = {
    'Model': [
        'Logistic Regression', 'K-Nearest Neighbors', 'Random Forest',
        'Grid Search + Random Forest', 'Gradient Boosting Machine',
        'Grid Search + GBM', 'XGBoost',
        'Grid Search + XGBoost', 'LightGBM', 'Grid Search + LightGBM'
    ],
    'AUC-ROC': [
        m1_auc_roc, m2_auc_roc, m3_auc_roc,
        m4_auc_roc, m5_auc_roc, m6_auc_roc,
        m7_auc_roc, m8_auc_roc, m9_auc_roc,
        m10_auc_roc
    ],
    'Accuracy': [
        m1_accuracy, m2_accuracy, m3_accuracy,
        m4_accuracy, m5_accuracy, m6_accuracy,
        m7_accuracy, m8_accuracy, m9_accuracy,
        m10_accuracy
    ],
    'Precision': [
        m1_precision, m2_precision, m3_precision,
        m4_precision, m5_precision, m6_precision,
        m7_precision, m8_precision, m9_precision,
        m10_precision
    ],
    'Recall': [
        m1_recall, m2_recall, m3_recall,
        m4_recall, m5_recall, m6_recall,
        m7_recall, m8_recall, m9_recall,
        m10_recall
    ],
    'F1 Score': [
        m1_f1, m2_f1, m3_f1,
        m4_f1, m5_f1, m6_f1,
        m7_f1, m8_f1, m9_f1,
        m10_f1
    ],
    'Confusion Matrix': [
        m1_conf_matrix, m2_conf_matrix, m3_conf_matrix,
        m4_conf_matrix, m5_conf_matrix, m6_conf_matrix,
        m7_conf_matrix, m8_conf_matrix, m9_conf_matrix,
        m10_conf_matrix
    ]
}

# DataFrame
df_resultados = pd.DataFrame(resultados)

# Imprimir
print("\n*****\nResumen de resultados para cada modelo:")
display(df_resultados)
# Out:
# *****
# Resumen de resultados para cada modelo:
#                          Model   AUC-ROC  Accuracy  Precision    Recall  \
# 0          Logistic Regression  0.831666  0.736131   0.901442  0.721848
# 1          K-Nearest Neighbors  0.792257  0.706259   0.906494  0.671800
# 2                Random Forest  0.839343  0.741110   0.913097  0.717998
# 3  Grid Search + Random Forest  0.844507  0.730441   0.918782  0.696824
# 4    Gradient Boosting Machine  0.837294  0.735420   0.910209  0.712223
# 5            Grid Search + GBM  0.840223  0.737553   0.918750  0.707411
# 6                      XGBoost  0.797509  0.709815   0.887117  0.695861
# 7        Grid Search + XGBoost  0.841352  0.729018   0.921795  0.692012
# 8                     LightGBM  0.815981  0.723329   0.904229  0.699711
# 9       Grid Search + LightGBM  0.832004  0.734708   0.910099  0.711261
#
#    F1 Score         Confusion Matrix
# 0  0.801710  [[285, 82], [289, 750]]
# 1  0.771697  [[295, 72], [341, 698]]
# ...

# %%
# Lista de matrices de confusión
matrices = [m1_conf_matrix, m2_conf_matrix, m3_conf_matrix, m4_conf_matrix,
            m5_conf_matrix, m6_conf_matrix, m7_conf_matrix, m8_conf_matrix,
            m9_conf_matrix, m10_conf_matrix]
modelos = ['Logistic Regression', 'KNN Classifier', 'Random Forest',
           'Grid Search + Random Forest', 'GBM', 'Grid Search + GBM',
           'XGBoost', 'Grid Search + XGBoost', 'LightGBM', 'Grid Search + LightGBM']

# Subtramas
fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(20, 10))
axes = axes.flatten()

for i, (matrix, model) in enumerate(zip(matrices, modelos)):
    sns.heatmap(matrix, annot=True, fmt='d', cmap='Blues', ax=axes[i])
    axes[i].set_title(f'{model}')
    axes[i].set_xlabel('Previsto')
    axes[i].set_ylabel('Verdadero ')

# Imprimir
plt.tight_layout()
plt.show()

# %%
# inicialización
falsos_positivos = []
falsos_negativos = []

# Bucle
for matriz_confusion in df_resultados['Confusion Matrix']:
    fp = matriz_confusion[0, 1]
    fn = matriz_confusion[1, 0]
    falsos_positivos.append(fp)
    falsos_negativos.append(fn)

# Diagrama de barras
fig, ax = plt.subplots(figsize=(10, 5))
modelo_labels = df_resultados['Model']
x = range(len(modelo_labels))
width = 0.4

# Barras
bar1 = ax.bar(x, falsos_positivos, width, label='Falsos positivos')
bar2 = ax.bar([i + width for i in x], falsos_negativos,
              width, label='Falsos negativos')

# Título y etiquetas
ax.set_xlabel('Modelos')
ax.set_ylabel('Cantidad')
ax.set_title('Comparación de falsos positivos y falsos negativos por modelo')

ax.set_xticks([i + width / 2 for i in x])
ax.set_xticklabels(modelo_labels, rotation=45, ha='right')
ax.legend()

# Imprimir
plt.tight_layout()
plt.show()

# %%
# Lista de modelos
models = [
    ("Model 1: Logistic Regression", m1_auc_roc, m1_predictions_proba_valid),
    ("Model 2: KNN Classifier", m2_auc_roc, m2_predictions_proba_valid),
    ("Model 3: Random Forest", m3_auc_roc, m3_predictions_proba_valid),
    ("Model 4: Grid Search + Random Forest", m4_auc_roc, m4_predictions_proba_valid),
    ("Model 5: Gradient Boosting Machine (GBM)", m5_auc_roc, m5_predictions_proba_valid),
    ("Model 6: Grid Search + Gradient Boosting Machine (GBM)", m6_auc_roc, m6_predictions_proba_valid),
    ("Model 7: XGBoost", m7_auc_roc, m7_predictions_proba_valid),
    ("Model 8: Grid Search + XGBoost", m8_auc_roc, m8_predictions_proba_valid),
    ("Model 9: LightGBM", m9_auc_roc, m9_predictions_proba_valid),
    ("Model 10: Grid Search + LightGBM", m10_auc_roc, m10_predictions_proba_valid),
]

# Trama
plt.figure(figsize=(10, 8))

# Curva ROC
for model_name, auc_roc, predictions_proba in models:
    fpr, tpr, _ = roc_curve(target_valid, predictions_proba)
    plt.plot(fpr, tpr, label='%s (AUC-ROC=%0.4f)' % (model_name, auc_roc))

# Gráficos
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal
plt.xlabel('Índice de falsos positivos')
plt.ylabel('Índice de verdaderos positivos')
plt.title('Curvas ROC comparativas de los modelos')
plt.legend(loc='lower right')

# Imprimir
plt.show()

# %% [markdown]
# ### 6.1 Análisis de resultados <a id='eva1'></a>

# %% [markdown]
# - **AUC-ROC:** Los modelos Grid Search + Random Forest, Grid Search + Gradient Boosting Machine y Grid Search + Extreme Gradient Boosting (XGBoost) superan el umbral de 0,83 en AUC-ROC y muestran un rendimiento sólido.
# - **Accuracy:** TLos modelos de regresión logística, Random Forest, Gradient Boosting Machine, Grid Search + Extreme Gradient Boosting (XGBoost) y Grid Search + LightGBM alcanzan una precisión superior a 0,73, lo que indica una alta tasa de clasificación correcta.
# - **Precision and Recall:** La mayoría de los modelos tienen alta precisión en predicciones positivas, aunque la recuperación podría mejorarse en algunos modelos.
# - **F1 Score:** Los modelos de Regresión Logística y Random Forest tienen los mejores resultados en F1 Score, mostrando un buen equilibrio entre precisión y recuperación.
# - **Confusion Matrices:** Los modelos estándar Random Forest y Gradient Boosting Machine son los más equilibrados en términos de verdaderos positivos y negativos. Sin embargo, existe una tendencia en los modelos a tener más falsos negativos que falsos positivos, lo que indica una tendencia a subestimar la pérdida de clientes.

# %% [markdown]
# ### 6.2 Selección del modelo con el mejor rendimiento <a id='eva2'></a>
# - **El modelo Random Forest** es la mejor opción para este proyecto, considerando todas las métricas y la estabilidad de los resultados. Ofrece un **AUC-ROC, precisión, recuperación** y **puntuación F1** altos, junto con una **matriz de confusión** equilibrada, tiende a ser rápido en el entrenamiento y demuestra un buen rendimiento general en comparación con los otros modelos evaluados.
# - A continuación se muestra el **modelo Random Forest** con los mejores hiperparámetros seleccionados de la búsqueda en cuadrícula utilizada.

# %%
# Modelo con los mejores hiperparámetros
modelf = RandomForestClassifier(
    random_state=12345,
    max_depth=20,
    min_samples_leaf=10,
    n_estimators=50
)

# Reducción de muestreo
final_features_downsampled, final_target_downsampled = downsample(
    total_features_train, total_target_train)

# Entrenamiento
modelf.fit(final_features_downsampled, final_target_downsampled)

# Predicciones
mf_predictions_valid = modelf.predict(features_test)
mf_predictions_proba_valid = modelf.predict_proba(features_test)[:, 1]

# %%
# Métricas
mf_auc_roc = roc_auc_score(target_test, mf_predictions_proba_valid)
mf_accuracy = accuracy_score(target_test, mf_predictions_valid)
mf_precision = precision_score(target_test, mf_predictions_valid)
mf_recall = recall_score(target_test, mf_predictions_valid)
mf_f1 = f1_score(target_test, mf_predictions_valid)
mf_conf_matrix = confusion_matrix(target_test, mf_predictions_valid)

# Imprimir
print("\n*****\nModelo final: Random Forest")
print(f"AUC-ROC: {mf_auc_roc:.2f}")
print(f"Accuracy: {mf_accuracy:.2f}")
print(f"Precision: {mf_precision:.2f}")
print(f"Recall: {mf_recall:.2f}")
print(f"F1 Score: {mf_f1:.2f}")

# Imprimir matriz de confusión
print("Confusion Matrix:")
print(mf_conf_matrix)
# Out:
# *****
# Modelo final: Random Forest
# AUC-ROC: 0.86
# Accuracy: 0.76
# Precision: 0.91
# Recall: 0.74
# F1 Score: 0.81
# Confusion Matrix:
# [[313  76]
#  [267 751]]

# %%
# Definición de gráfico
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Matriz de confusión
disp = ConfusionMatrixDisplay(confusion_matrix=mf_conf_matrix)
disp.plot(ax=ax1, cmap='Blues')
ax1.set_title(
    "Matriz de confusión (Modelo final: Random Forest)")
ax1.set_xlabel("Predicción")
ax1.set_ylabel("Actual")
tick_labels = ['Falso', 'Verdadero']
ax1.set_xticks(ticks=[0, 1], labels=tick_labels)
ax1.set_yticks(ticks=[0, 1], labels=tick_labels)

# ROC Curve
fpr, tpr, _ = roc_curve(target_test, mf_predictions_proba_valid)
ax2.plot(fpr, tpr, label='Curva ROC (AUC-ROC=%0.4f)' % mf_auc_roc)
ax2.set_xlabel('Índice de falsos positivos')
ax2.set_ylabel('Índice de verdaderos positivos')
ax2.set_title('Curva ROC (Modelo final: Random Forest)')
ax2.legend(loc='lower right')

# Print
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 6.3 Análisis del modelo con mejor desempeño <a id='eva3'></a>
# En el conjunto de datos original, hay un desequilibrio, con más casos de clientes que no abandonaron la cuenta (clase negativa) en comparación con los que sí lo hicieron (clase positiva). Los resultados del modelo **Random Forest** en el conjunto de prueba se analizan a continuación:
# - **AUC-ROC:** El valor de **0,86** indica que el modelo funciona bien en términos de discriminación entre clases positivas y negativas. Esto sugiere que el modelo es eficaz para distinguir entre clientes que se darán de baja y aquellos que no.
# - **Accuracy:** Con un **76%**, el modelo clasifica correctamente una gran proporción de casos, lo que es positivo. Sin embargo, en problemas de desequilibrio de clases como este, es fundamental evaluar también otras métricas como la precisión, la recuperación y la puntuación F1 para obtener una visión completa del rendimiento del modelo.
# - **Precision:** La precisión de **0,91** significa que, de todas las predicciones positivas realizadas por el modelo, el 91 % fueron correctas. Esto indica que cuando el modelo predice que un cliente se irá, existe una alta probabilidad de que así sea.
# - **Recall:** Con un índice de recuperación de **0,74**, el modelo es eficaz para identificar a los clientes que tienen una alta probabilidad de abandonar la tienda. Sin embargo, este valor de recuperación también sugiere que el modelo aún no detecta algunos casos de abandono.
# - **F1 Score:** La puntuación F1 de **0,81**, una medida combinada de precisión y recuperación, muestra un buen equilibrio entre las dos métricas. Esto es particularmente importante en problemas de desequilibrio de clases, como la predicción de la pérdida de clientes.
# - **Confusion Matrix:**
#     - **Verdaderos positivos = 751:** clientes que el modelo predijo correctamente que se darían de baja y lo hicieron.
#     - **Verdaderos negativos = 313:** clientes que el modelo predijo correctamente que no se darían de baja y no lo hicieron.
#     - **Falsos positivos = 76:** clientes que el modelo predijo incorrectamente que se darían de baja, pero no lo hicieron.
#     - **Falsos negativos = 267:** clientes que el modelo predijo incorrectamente que no se darían de baja, pero lo hicieron.
#     - El modelo es eficaz para captar la mayoría de los casos de clientes que realmente abandonan la empresa. Sin embargo, esas predicciones falsas pueden dar lugar a acciones de retención innecesarias o, por el contrario, a la pérdida de oportunidades de retener a los clientes que realmente quieren abandonar la empresa.

# %% [markdown]
# [Volver a Contenidos](#back)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Has realizado una evaluación completa y bien estructurada de los modelos. La comparación detallada de métricas, junto con las visualizaciones de matrices de confusión y curvas ROC, facilita la identificación del mejor modelo. La justificación de la elección de **Random Forest** como el modelo final está bien fundamentada con análisis de rendimiento y equilibrio de clases. ¡Gran trabajo!
# </div>

# %% [markdown]
# ***
# ## 7. Conclusiones del proyecto <a id='con0'></a>

# %% [markdown]
# ### 7.1 Resumen del proyecto <a id='con1'></a>
# - Este proyecto implicó predecir la pérdida de clientes para Interconnect mediante técnicas de aprendizaje automático. Se exploraron cuatro conjuntos de datos principales: **df_contract**, **df_personal**, **df_internet** y **df_phone**, que se integraron en un único DataFrame para facilitar el análisis, la limpieza y el modelado.
# - Al aplicar varios modelos de clasificación, como la regresión logística, el clasificador KNN, Random Forest, XGBoost y LightGBM (incluida una variación con búsqueda en cuadrícula para algunos de ellos), se seleccionó un modelo final basado en Random Forest debido a su solidez y rendimiento en métricas clave como AUC-ROC, precisión, recuperación y puntaje F1.

# %% [markdown]
# ### 7.2 Conclusión <a id='con2'></a>
# El modelo Random Forest ofrece un rendimiento sólido y equilibrado en la predicción de la pérdida de clientes, destacando por su precisión y su capacidad para discriminar correctamente entre clases. A pesar de la presencia de algunos falsos positivos y negativos, la aplicación de este modelo podría contribuir significativamente a mejorar las estrategias de retención de clientes.

# %% [markdown]
# ### 7.3 Posibilidades de mejora futuras <a id='con3'></a>
# - El número de falsos positivos (76) es relativamente bajo en comparación con el número de verdaderos positivos, que es positivo, pero aún así podrían representar costos adicionales si se toman medidas de retención innecesarias.
# - El número de falsos negativos (267) es significativo y representa casos en los que el modelo no identificó correctamente a los clientes que se fueron. Este tipo de error es crítico porque representa oportunidades perdidas para intervenir y retener a los clientes que tienen una alta probabilidad de abandonar la empresa.
# - El modelo Random Forest ha demostrado ser eficaz para predecir la pérdida de clientes, con una puntuación F1 sólida y una buena precisión. Sin embargo, se podría mejorar el recall para identificar más casos de clientes que realmente se van.
#
# **Este modelo se puede implementar con confianza para respaldar las estrategias de retención de clientes. Sin embargo, se recomienda monitorear continuamente su desempeño y considerar ajustes adicionales para minimizar tanto los falsos positivos como los falsos negativos y optimizar el equilibrio entre precisión y recall.**

# %% [markdown]
# [Volver a Contenidos](#back)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Has estructurado una conclusión clara y bien fundamentada. Destacas los logros del proyecto, justificas la elección del modelo final y señalas oportunidades de mejora de manera precisa. La recomendación de monitorear el desempeño del modelo y optimizar el equilibrio entre precisión y recall es acertada. ¡Excelente trabajo!
# </div>

# %% [markdown]
# # Comentario general del revisor

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# ¡Felicidades Bo Torp! Tu proyecto está **aprobado**. Se nota un gran esfuerzo y dedicación en cada etapa del análisis, desde la preparación de datos hasta la evaluación de los modelos. Has demostrado un excelente manejo de técnicas avanzadas de aprendizaje automático, optimización de modelos y evaluación de métricas clave. A continuación, destaco los puntos positivos y algunas áreas interesantes para seguir investigando:
#
# **Puntos Positivos:**
# - Preparación y limpieza de datos: La eliminación de datos irrelevantes, la codificación de variables categóricas y el escalado de características se realizaron de manera estructurada y eficiente.
# - Balanceo de clases: La aplicación de técnicas de submuestreo y sobremuestreo demuestra un entendimiento sólido sobre la importancia del equilibrio de clases en modelos de clasificación.
# - Comparación de múltiples modelos: Probaste diversas técnicas, desde regresión logística hasta modelos avanzados como Random Forest, XGBoost y LightGBM, con variaciones mediante búsqueda en cuadrícula para optimizar los resultados.
# - Evaluación de modelos bien fundamentada: Las métricas utilizadas (AUC-ROC, precisión, recall, F1-score) permiten una evaluación robusta y la selección del mejor modelo basado en un análisis cuantitativo riguroso.
# - Visualizaciones claras y explicativas: Los gráficos utilizados (matrices de confusión, curvas ROC, distribuciones de clases) enriquecen la interpretación de los resultados y facilitan la comunicación de hallazgos clave.
#
# **Áreas para Seguir Investigando:**
# - Ajuste del umbral de clasificación: Explorar la calibración de probabilidades y la optimización del umbral de decisión podría ayudar a reducir falsos negativos sin comprometer la precisión.
# - Ensemble learning: Evaluar la combinación de modelos (por ejemplo, un ensamble entre XGBoost y Random Forest) podría generar mejoras adicionales en el rendimiento del modelo final.
# - Feature Engineering adicional: Investigar la creación de nuevas variables a partir de las características existentes podría proporcionar información más rica y mejorar la capacidad predictiva del modelo.
# - Optimización del balanceo de clases: Considerar técnicas más avanzadas como SMOTE o ADASYN para mejorar el rendimiento en datos desbalanceados.
# - Implementación en producción: Explorar estrategias para la monitorización del modelo en un entorno real, asegurando que su rendimiento se mantenga estable con datos en vivo.
#
# En general, el proyecto es sólido, bien estructurado y demuestra una comprensión profunda del modelado predictivo en aprendizaje automático. 🚀📊 ¡Sigue así, estás haciendo un trabajo excepcional! 💪🎯😃
#
# </div>

# %% [markdown]
# ***
# ## 8. Informe de solución <a id='inf0'></a>

# %% [markdown]
# ### 8.1 ¿Qué pasos del plan se realizaron y qué pasos se omitieron (explica por qué)? <a id='inf1'></a>
# ##### ¿Qué se realizó en el proyecto?
# El objetivo de este proyecto era crear un modelo de aprendizaje automático que pudiera predecir con precisión el riesgo de que un cliente abandonara los servicios del operador de telecomunicaciones Interconnect. Durante el proyecto se han tomado varias medidas para garantizar conjuntos de datos limpios, óptimos y equilibrados y para asegurar un rendimiento óptimo del modelo. A continuación se muestran los pasos generales que se tomaron para garantizar un resultado óptimo.
#
# - **Recopilación de datos**: antes de que el proyecto fuera entregado al científico de datos, se recopilaron cuatro conjuntos de datos. Estos cuatro conjuntos de datos fueron:
#     - **contract.csv**: contiene información contractual como tipo de facturación, método de pago y cargos mensuales y anuales y, además, la fecha de inicio y, en caso de que se hubiera rescindido un contrato, también incluía una fecha de finalización.
#     - **personal.csv**: contiene datos personales de los clientes de la empresa. Estos detalles personales eran género, si eran personas mayores, si estaban en una relación de pareja o si eran dependientes.
#     - **internet.csv**: contiene el tipo de servicio de Internet contratado y los complementos conectados a ese servicio. Estos complementos incluían seguridad en línea, copia de seguridad en línea, protección de dispositivos, soporte técnico, transmisión de TV y transmisión de películas.
#     - **phone.csv**: si un cliente tiene varias líneas telefónicas conectadas al servicio.
#     - Cada uno de los conjuntos de datos contenía un ID de cliente único que permitía seguir a un cliente en todos los conjuntos de datos.
#
# - **Preprocesamiento**: a continuación, se evaluaron y analizaron los conjuntos de datos para encontrar y corregir las deficiencias que obstaculizarían la creación del modelo. No se encontraron valores duplicados y, en general, los datos estaban relativamente limpios. Se tuvieron que corregir los nombres de las columnas y cambiar algunos valores a un formato diferente.
# - **Análisis exploratorio de datos (EDA)**: antes de realizar el EDA, los cuatro conjuntos de datos se fusionaron en uno solo. Luego se realizó un análisis exhaustivo para encontrar valores atípicos, inconsistencias y cualquier patrón de abandono de clientes oculto en los conjuntos de datos.
# - **Preprocesamiento de datos**: durante esta fase, el objetivo se centró en dos cosas. En primer lugar, los conjuntos de datos originales contenían una gran cantidad de datos del tipo "objeto". Para que el modelo de ML funcionara sin problemas, esto debía modificarse. Esto se hizo utilizando "One-Hot Encoding" para convertir los datos en datos booleanos. En segundo lugar, los datos originales no estaban equilibrados y se equilibraron utilizando técnicas de aumento y reducción de escala.
# - **Entrenamiento y evaluación del modelo** - El siguiente paso fue entrenar el modelo donde se probaron diferentes modelos y configuraciones para encontrar el modelo y la combinación de parámetros óptimos. Durante esta fase, se probaron y posteriormente se evaluaron utilizando, entre otros, la precisión, la matriz de confusión y la curva ROC.
# - Por último, se eligió el mejor modelo en función de estas métricas. Esto se explicará con más detalle más adelante.
#
# ##### ¿Qué se omitió en el proyecto?
#
# Se debe investigar más a fondo la optimización del modelo final. Durante el proyecto se probaron y optimizaron varios modelos mediante técnicas de ajuste de hiperparámetros. Sin embargo, debido a las limitaciones de tiempo y al tamaño limitado del conjunto de datos, se pudieron investigar más exhaustivamente para obtener una combinación de parámetros aún mejor y un rendimiento del modelo aún mejor. Además, se debería haber trabajado mucho más para garantizar una mejor optimización del equilibrio de clases. Esto se podría haber hecho utilizando técnicas como SMOTE y ADASYN. Sin embargo, debido a limitaciones de tiempo, no fue posible explorarlas más a fondo.

# %% [markdown]
# ### 8.2 ¿Qué dificultades encontraste y cómo lograste resolverlas? <a id='inf2'></a>
#
# Durante el desarrollo de este proyecto surgieron varios desafíos y dificultades, los cuales se describen a continuación.
#
# - **Desequilibrios en los datos:** el conjunto de datos original presentaba un desequilibrio importante en términos de contratos activos e inactivos. Los datos desequilibrados en el aprendizaje automático se consideran malos porque pueden generar modelos sesgados que aprenden principalmente a predecir la clase mayoritaria, lo que genera un rendimiento deficiente en la clase minoritaria, lo que dificulta la clasificación precisa de eventos importantes pero menos frecuentes y, a menudo, genera métricas de precisión engañosas al evaluar el rendimiento general del modelo.
#     - ***Solución:** El problema del desequilibrio se resolvió mediante técnicas sencillas de sobremuestreo y submuestreo. Sin embargo, como ya se ha dicho, se trata de un área que se debe explorar más a fondo.*
# - **Seleccionar las variables correctas:** No fue inmediatamente obvio qué combinación de características, tipo de plan, duración del contrato y uso de servicios adicionales eran más óptimas y efectivas para predecir la pérdida de clientes.
#     - ***Solución:** La EDA en conjunto con un proceso de selección de características utilizando modelos como Random Forest ayudó a clarificar e identificar las variables más significativas para predecir la pérdida de clientes.*

# %% [markdown]
# ### 8.3 ¿Cuáles fueron algunos de los pasos clave para resolver la tarea? <a id='inf3'></a>
# 1. **Limpieza y transformación de los datos:**
# <br> La limpieza y transformación de datos fue un paso crucial en el análisis de datos porque aseguró la precisión y la consistencia de los datos, lo que permitió obtener información confiable al eliminar errores, inconsistencias y problemas de formato, lo que en última instancia condujo a resultados más significativos primero del análisis y luego de los modelos.
# <br>
# <br>
# **¿Para qué se utilizó el Limpieza y preprocesamiento?:**
# <br>
#     - Mejorar la calidad de los datos: al identificar y corregir errores como nombres de columnas, valores faltantes y valores atípicos, ayudó a mejorar la confiabilidad general de su conjunto de datos.
#     - Rendimiento optimizado del modelo: los datos depurados y transformados ayudaron a mejorar significativamente el rendimiento del modelado predictivo.
#     - Sesgo reducido: al reducir el desequilibrio en los datos, ayudó a minimizar el riesgo de resultados sesgados debido a datos sesgados.
#
# 2. **Análisis exploratorio de los datos (EDA):**
# <br> El análisis exploratorio de datos (EDA) se realizó para obtener una comprensión integral de los conjuntos de datos mediante la identificación de patrones, relaciones entre variables, valores atípicos y posibles problemas dentro de los datos antes de realizar suposiciones, lo que ayudó a guiar el análisis posterior, la construcción de modelos y la toma de decisiones.
# <br>
# <br>
# **¿Para qué se utilizó el EDA?:**
#     - Descubrir patrones y relaciones ocultos: ayudó a visualizar y analizar datos para descubrir tendencias, correlaciones y conexiones entre variables que podrían no ser evidentes a simple vista.
#     - Evaluar la calidad de los datos: me permitió verificar valores faltantes, inconsistencias y posibles errores en el proceso de recopilación de datos.
#     - Ingeniería de características y selección de modelos: brindó una comprensión de la distribución y las características de las variables y guió la selección de características y las decisiones de construcción de modelos.
#     - Limpieza y preprocesamiento de datos: ayudó a identificar áreas en las que era necesaria una mayor limpieza o transformación de datos antes de continuar.
#
# 3. **Entrenamiento de múltiples modelos:** <br>
# <br>
# Para encontrar el modelo con mejor rendimiento se probaron diferentes modelos y configuraciones. Los modelos probados fueron:
#     - Regresión logística
#     - K-vecinos más cercanos
#     - Bosque aleatorio
#     - Búsqueda en cuadrícula + Bosque aleatorio
#     - Máquina de refuerzo de gradiente
#     - Búsqueda en cuadrícula + GBM
#     - XGBoost
#     - Búsqueda en cuadrícula + XGBoost
#     - LightGBM
#     - Búsqueda en cuadrícula + LightGBM
#
# 4. **Evaluación del modelo::** <br>
# <br>
# Finalmente, se evaluaron los modelos para evaluar el rendimiento del modelo y evitar el sobreajuste en función de las siguientes métricas:
#     - AUC-ROC
#     - Exactitud
#     - Precisión
#     - Recordatorio
#     - Puntuación F1
#     - Matriz de confusión

# %% [markdown]
# ### 8.4 ¿Cuál es tu modelo final y qué nivel de calidad tiene? <a id='inf4'></a>
#
# En el conjunto de datos original, hay un desequilibrio, con más casos de clientes que no abandonaron la cuenta (clase negativa) en comparación con los que sí lo hicieron (clase positiva). Los resultados del modelo **Random Forest** en el conjunto de prueba se analizan a continuación:
# - **AUC-ROC:** El valor de **0,86** indica que el modelo funciona bien en términos de discriminación entre clases positivas y negativas. Esto sugiere que el modelo es eficaz para distinguir entre clientes que se darán de baja y aquellos que no.
# - **Accuracy:** Con un **76%**, el modelo clasifica correctamente una gran proporción de casos, lo que es positivo. Sin embargo, en problemas de desequilibrio de clases como este, es fundamental evaluar también otras métricas como la precisión, la recuperación y la puntuación F1 para obtener una visión completa del rendimiento del modelo.
# - **Precision:** La precisión de **0,91** significa que, de todas las predicciones positivas realizadas por el modelo, el 91 % fueron correctas. Esto indica que cuando el modelo predice que un cliente se irá, existe una alta probabilidad de que así sea.
# - **Recall:** Con un índice de recuperación de **0,74**, el modelo es eficaz para identificar a los clientes que tienen una alta probabilidad de abandonar la tienda. Sin embargo, este valor de recuperación también sugiere que el modelo aún no detecta algunos casos de abandono.
# - **F1 Score:** La puntuación F1 de **0,81**, una medida combinada de precisión y recuperación, muestra un buen equilibrio entre las dos métricas. Esto es particularmente importante en problemas de desequilibrio de clases, como la predicción de la pérdida de clientes.
# - **Confusion Matrix:**
#     - **Verdaderos positivos = 751:** clientes que el modelo predijo correctamente que se darían de baja y lo hicieron.
#     - **Verdaderos negativos = 313:** clientes que el modelo predijo correctamente que no se darían de baja y no lo hicieron.
#     - **Falsos positivos = 76:** clientes que el modelo predijo incorrectamente que se darían de baja, pero no lo hicieron.
#     - **Falsos negativos = 267:** clientes que el modelo predijo incorrectamente que no se darían de baja, pero lo hicieron.
#     - El modelo es eficaz para captar la mayoría de los casos de clientes que realmente abandonan la empresa. Sin embargo, esas predicciones falsas pueden dar lugar a acciones de retención innecesarias o, por el contrario, a la pérdida de oportunidades de retener a los clientes que realmente quieren abandonar la empresa.

# %% [markdown]
# [Volver a Contenidos](#back)
